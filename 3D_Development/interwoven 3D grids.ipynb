# %%
import matplotlib.pyplot as plt
import numpy as np
#import random
# %matplotlib notebook

# %%
#interwoven 3D grid with index 2*1*1, every copy of the motif in a different color:

num_steps = 25 #choosing how densely the lines are sampled. Namely, each straight line is sampled by num_step points.

fig = plt.figure(figsize=(12, 12))
ax = fig.add_subplot(projection='3d')



#These for-loops will copy the motif in 2x2x2 different translates.
for x_iter in range(0,2,1):
    for y_iter in range(0,2,1):
        for z_iter in range(0,2,1):
            
            #I want to make a path from (0,0,0) to (2,0,0) thus in x-direction, but skipping one integer point.
            #To avoid intersection with its copies, I have to make the path curved. 
            #Thus it consits of 3 straight lines: first part, second part, and third part, together forming a curve.
            #The second and third part form an arc, under which the copy of the first part can pass underneath.
            x_direction_first_part_x_vals = np.linspace(x_iter,      x_iter+0.3, num_steps) 
            x_direction_first_part_y_vals = np.linspace(y_iter,      y_iter+0.4, num_steps)
            x_direction_first_part_z_vals = np.linspace(z_iter,      z_iter,     num_steps)

            x_direction_second_part_x_vals = np.linspace(x_iter+0.3, x_iter+1.2, num_steps) 
            x_direction_second_part_y_vals = np.linspace(y_iter+0.4, y_iter+0.2, num_steps)
            x_direction_second_part_z_vals = np.linspace(z_iter,     z_iter+0.4, num_steps)
            
            x_direction_third_part_x_vals = np.linspace(x_iter+1.2,  x_iter+2,   num_steps) 
            x_direction_third_part_y_vals = np.linspace(y_iter+0.2,  y_iter,     num_steps)
            x_direction_third_part_z_vals = np.linspace(z_iter+0.4,  z_iter,     num_steps)
            
            
            #In y-direction I decided not to skip any integer points, so connecting (0,0,0) directly with (0,1,0).
            #This can be done with a straight line, thus only one part, without risking intersections.
            y_direction_first_part_x_vals = np.linspace(x_iter,      x_iter,     num_steps) 
            y_direction_first_part_y_vals = np.linspace(y_iter,      y_iter+1,   num_steps)
            y_direction_first_part_z_vals = np.linspace(z_iter,      z_iter,     num_steps)

            #Same in z-direction.
            z_direction_first_part_x_vals = np.linspace(x_iter,      x_iter,     num_steps) 
            z_direction_first_part_y_vals = np.linspace(y_iter,      y_iter,     num_steps)
            z_direction_first_part_z_vals = np.linspace(z_iter,      z_iter+1,   num_steps)

            
            
            #Concatenating the individual pieces:
            x_vals = np.concatenate((x_direction_first_part_x_vals, x_direction_second_part_x_vals, x_direction_third_part_x_vals, y_direction_first_part_x_vals, z_direction_first_part_x_vals))
            y_vals = np.concatenate((x_direction_first_part_y_vals, x_direction_second_part_y_vals, x_direction_third_part_y_vals, y_direction_first_part_y_vals, z_direction_first_part_y_vals))
            z_vals = np.concatenate((x_direction_first_part_z_vals, x_direction_second_part_z_vals, x_direction_third_part_z_vals, y_direction_first_part_z_vals, z_direction_first_part_z_vals))

            #scatter plot for each possible shift from the for-loop in a different color.
            ax.scatter(x_vals, y_vals, z_vals)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="684">

# %%
#interwoven 3D grid with index 2*1*1, the two components in two different colors:

num_steps = 25

fig = plt.figure(figsize=(9, 9))
ax = fig.add_subplot(projection='3d')

#These for-loops will copy the motif in 2x2x2 different translates, but skipping one in x-direction, so that we only get the connected piece.
for x_iter in range(0,4,2):
    for y_iter in range(0,2,1):
        for z_iter in range(0,2,1):

            x_direction_first_part_x_vals = np.linspace(x_iter,      x_iter+0.3, num_steps) 
            x_direction_first_part_y_vals = np.linspace(y_iter,      y_iter+0.4, num_steps)
            x_direction_first_part_z_vals = np.linspace(z_iter,      z_iter,     num_steps)

            x_direction_second_part_x_vals = np.linspace(x_iter+0.3, x_iter+1.2, num_steps) 
            x_direction_second_part_y_vals = np.linspace(y_iter+0.4, y_iter+0.2, num_steps)
            x_direction_second_part_z_vals = np.linspace(z_iter,     z_iter+0.4, num_steps)
            
            x_direction_third_part_x_vals = np.linspace(x_iter+1.2,  x_iter+2,   num_steps) 
            x_direction_third_part_y_vals = np.linspace(y_iter+0.2,  y_iter,     num_steps)
            x_direction_third_part_z_vals = np.linspace(z_iter+0.4,  z_iter,     num_steps)
            
            
            
            y_direction_first_part_x_vals = np.linspace(x_iter,      x_iter,     num_steps) 
            y_direction_first_part_y_vals = np.linspace(y_iter,      y_iter+1,   num_steps)
            y_direction_first_part_z_vals = np.linspace(z_iter,      z_iter,     num_steps)

            
            z_direction_first_part_x_vals = np.linspace(x_iter,      x_iter,     num_steps) 
            z_direction_first_part_y_vals = np.linspace(y_iter,      y_iter,     num_steps)
            z_direction_first_part_z_vals = np.linspace(z_iter,      z_iter+1,   num_steps)

            
            

            x_vals = np.concatenate((x_direction_first_part_x_vals, x_direction_second_part_x_vals, x_direction_third_part_x_vals, y_direction_first_part_x_vals, z_direction_first_part_x_vals))
            y_vals = np.concatenate((x_direction_first_part_y_vals, x_direction_second_part_y_vals, x_direction_third_part_y_vals, y_direction_first_part_y_vals, z_direction_first_part_y_vals))
            z_vals = np.concatenate((x_direction_first_part_z_vals, x_direction_second_part_z_vals, x_direction_third_part_z_vals, y_direction_first_part_z_vals, z_direction_first_part_z_vals))

            ax.scatter(x_vals, y_vals, z_vals, color='k') #plotting one connected component in black
            ax.scatter(x_vals+1, y_vals, z_vals, color='b') #and the other, shifted by (1,0,0) in blue

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
#interwoven 3D grid with index 2*1*1, just one motif, as example point set to input in periodic persistence software:

num_steps = 20

fig = plt.figure(figsize=(9, 9))
ax = fig.add_subplot(projection='3d')

#Now we don't want a for-loop but instead only one copy of the motif, thus fixed values here.
x_iter=0
y_iter=0
z_iter=0

x_direction_first_part_x_vals = np.linspace(x_iter,      x_iter+0.3, num_steps) 
x_direction_first_part_y_vals = np.linspace(y_iter,      y_iter+0.4, num_steps)
x_direction_first_part_z_vals = np.linspace(z_iter,      z_iter,     num_steps)

x_direction_second_part_x_vals = np.linspace(x_iter+0.3, x_iter+1.2, num_steps) 
x_direction_second_part_y_vals = np.linspace(y_iter+0.4, y_iter+0.2, num_steps)
x_direction_second_part_z_vals = np.linspace(z_iter,     z_iter+0.4, num_steps)

x_direction_third_part_x_vals = np.linspace(x_iter+1.2,  x_iter+1.99,num_steps) #I end a bit away from the end, so that no two points are identitcal.
x_direction_third_part_y_vals = np.linspace(y_iter+0.2,  y_iter,     num_steps)
x_direction_third_part_z_vals = np.linspace(z_iter+0.4,  z_iter,     num_steps)


y_direction_first_part_x_vals = np.linspace(x_iter,      x_iter,     num_steps) 
y_direction_first_part_y_vals = np.linspace(y_iter+0.01, y_iter+0.99,num_steps) #I start and end a bit away from the ends, so that no two points are identitcal.
y_direction_first_part_z_vals = np.linspace(z_iter,      z_iter,     num_steps)


z_direction_first_part_x_vals = np.linspace(x_iter,      x_iter,     num_steps) 
z_direction_first_part_y_vals = np.linspace(y_iter,      y_iter,     num_steps)
z_direction_first_part_z_vals = np.linspace(z_iter+0.01, z_iter+0.99,num_steps) #I start and end a bit away from the ends, so that no two points are identitcal.


x_vals = np.concatenate((x_direction_first_part_x_vals, x_direction_second_part_x_vals, x_direction_third_part_x_vals, y_direction_first_part_x_vals, z_direction_first_part_x_vals))
y_vals = np.concatenate((x_direction_first_part_y_vals, x_direction_second_part_y_vals, x_direction_third_part_y_vals, y_direction_first_part_y_vals, z_direction_first_part_y_vals))
z_vals = np.concatenate((x_direction_first_part_z_vals, x_direction_second_part_z_vals, x_direction_third_part_z_vals, y_direction_first_part_z_vals, z_direction_first_part_z_vals))


#To bring it into one unit cell (the unit cell is the standard 1x1x1 cubic unit cell)
x_vals = x_vals - np.floor(x_vals)
#y_vals = y_vals - np.floor(y_vals) #not necessary because already between 0 and 1
#z_vals = z_vals - np.floor(z_vals) #not necessary because already between 0 and 1
 
ax.scatter(x_vals, y_vals, z_vals)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
#interwoven 3D grid with index 2*2*2, every copy of the motif in a different color:
num_steps = 25

fig = plt.figure(figsize=(9, 9))
ax = fig.add_subplot(projection='3d')

for x_iter in range(0,2,1):
    for y_iter in range(0,2,1):
        for z_iter in range(0,2,1):

            x_direction_first_part_x_vals = np.linspace(x_iter,      x_iter+0.3, num_steps) 
            x_direction_first_part_y_vals = np.linspace(y_iter,      y_iter+0.4, num_steps)
            x_direction_first_part_z_vals = np.linspace(z_iter,      z_iter,     num_steps)

            x_direction_second_part_x_vals = np.linspace(x_iter+0.3, x_iter+1.2, num_steps) 
            x_direction_second_part_y_vals = np.linspace(y_iter+0.4, y_iter+0.2, num_steps)
            x_direction_second_part_z_vals = np.linspace(z_iter,     z_iter+0.4, num_steps)
            
            x_direction_third_part_x_vals = np.linspace(x_iter+1.2,  x_iter+2,   num_steps) 
            x_direction_third_part_y_vals = np.linspace(y_iter+0.2,  y_iter,     num_steps)
            x_direction_third_part_z_vals = np.linspace(z_iter+0.4,  z_iter,     num_steps)
            
            
            #Now we do the same kind of trick in y- and z-direction as well.
            #I.e. Also in y-direction we skip an integer point by connecting (0,0,0) directly with (0,2,0).
            #But not with a straight line but with a curved line consisting of 3 pieces instead.
            #The curve is the same as before. I just permuted the coordinates.
            y_direction_first_part_x_vals = np.linspace(x_iter,      x_iter,     num_steps) 
            y_direction_first_part_y_vals = np.linspace(y_iter,      y_iter+0.3, num_steps)
            y_direction_first_part_z_vals = np.linspace(z_iter,      z_iter+0.4, num_steps)

            y_direction_second_part_x_vals = np.linspace(x_iter,     x_iter+0.4, num_steps) 
            y_direction_second_part_y_vals = np.linspace(y_iter+0.3, y_iter+1.2, num_steps)
            y_direction_second_part_z_vals = np.linspace(z_iter+0.4, z_iter+0.2, num_steps)
            
            y_direction_third_part_x_vals = np.linspace(x_iter+0.4,  x_iter,     num_steps) 
            y_direction_third_part_y_vals = np.linspace(y_iter+1.2,  y_iter+2,   num_steps)
            y_direction_third_part_z_vals = np.linspace(z_iter+0.2,  z_iter,     num_steps)
            
            #And in z-direction as well:
            z_direction_first_part_x_vals = np.linspace(x_iter,      x_iter+0.4, num_steps) 
            z_direction_first_part_y_vals = np.linspace(y_iter,      y_iter,     num_steps)
            z_direction_first_part_z_vals = np.linspace(z_iter,      z_iter+0.3, num_steps)

            z_direction_second_part_x_vals = np.linspace(x_iter+0.4, x_iter+0.2, num_steps) 
            z_direction_second_part_y_vals = np.linspace(y_iter,     y_iter+0.4, num_steps)
            z_direction_second_part_z_vals = np.linspace(z_iter+0.3, z_iter+1.2, num_steps)
            
            z_direction_third_part_x_vals = np.linspace(x_iter+0.2,  x_iter,     num_steps) 
            z_direction_third_part_y_vals = np.linspace(y_iter+0.4,  y_iter,     num_steps)
            z_direction_third_part_z_vals = np.linspace(z_iter+1.2,  z_iter+2,   num_steps)
            
            

            x_vals = np.concatenate((x_direction_first_part_x_vals, x_direction_second_part_x_vals, x_direction_third_part_x_vals, y_direction_first_part_x_vals, y_direction_second_part_x_vals, y_direction_third_part_x_vals, z_direction_first_part_x_vals, z_direction_second_part_x_vals, z_direction_third_part_x_vals))
            y_vals = np.concatenate((x_direction_first_part_y_vals, x_direction_second_part_y_vals, x_direction_third_part_y_vals, y_direction_first_part_y_vals, y_direction_second_part_y_vals, y_direction_third_part_y_vals, z_direction_first_part_y_vals, z_direction_second_part_y_vals, z_direction_third_part_y_vals))
            z_vals = np.concatenate((x_direction_first_part_z_vals, x_direction_second_part_z_vals, x_direction_third_part_z_vals, y_direction_first_part_z_vals, y_direction_second_part_z_vals, y_direction_third_part_z_vals, z_direction_first_part_z_vals, z_direction_second_part_z_vals, z_direction_third_part_z_vals))

            ax.scatter(x_vals, y_vals, z_vals)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
#interwoven 3D grid with index 2*2*2, every of the 8 components in a different color:
num_steps = 25

fig = plt.figure(figsize=(12, 12))
ax = fig.add_subplot(projection='3d')

for x_iter in range(0,4,2):
    for y_iter in range(0,4,2):
        for z_iter in range(0,4,2):

            x_direction_first_part_x_vals = np.linspace(x_iter,      x_iter+0.3, num_steps) 
            x_direction_first_part_y_vals = np.linspace(y_iter,      y_iter+0.4, num_steps)
            x_direction_first_part_z_vals = np.linspace(z_iter,      z_iter,     num_steps)

            x_direction_second_part_x_vals = np.linspace(x_iter+0.3, x_iter+1.2, num_steps) 
            x_direction_second_part_y_vals = np.linspace(y_iter+0.4, y_iter+0.2, num_steps)
            x_direction_second_part_z_vals = np.linspace(z_iter,     z_iter+0.4, num_steps)
            
            x_direction_third_part_x_vals = np.linspace(x_iter+1.2,  x_iter+2,   num_steps) 
            x_direction_third_part_y_vals = np.linspace(y_iter+0.2,  y_iter,     num_steps)
            x_direction_third_part_z_vals = np.linspace(z_iter+0.4,  z_iter,     num_steps)
            
            
            
            y_direction_first_part_x_vals = np.linspace(x_iter,      x_iter,     num_steps) 
            y_direction_first_part_y_vals = np.linspace(y_iter,      y_iter+0.3, num_steps)
            y_direction_first_part_z_vals = np.linspace(z_iter,      z_iter+0.4, num_steps)

            y_direction_second_part_x_vals = np.linspace(x_iter,     x_iter+0.4, num_steps) 
            y_direction_second_part_y_vals = np.linspace(y_iter+0.3, y_iter+1.2, num_steps)
            y_direction_second_part_z_vals = np.linspace(z_iter+0.4, z_iter+0.2, num_steps)
            
            y_direction_third_part_x_vals = np.linspace(x_iter+0.4,  x_iter,     num_steps) 
            y_direction_third_part_y_vals = np.linspace(y_iter+1.2,  y_iter+2,   num_steps)
            y_direction_third_part_z_vals = np.linspace(z_iter+0.2,  z_iter,     num_steps)
            
            
            z_direction_first_part_x_vals = np.linspace(x_iter,      x_iter+0.4, num_steps) 
            z_direction_first_part_y_vals = np.linspace(y_iter,      y_iter,     num_steps)
            z_direction_first_part_z_vals = np.linspace(z_iter,      z_iter+0.3, num_steps)

            z_direction_second_part_x_vals = np.linspace(x_iter+0.4, x_iter+0.2, num_steps) 
            z_direction_second_part_y_vals = np.linspace(y_iter,     y_iter+0.4, num_steps)
            z_direction_second_part_z_vals = np.linspace(z_iter+0.3, z_iter+1.2, num_steps)
            
            z_direction_third_part_x_vals = np.linspace(x_iter+0.2,  x_iter,     num_steps) 
            z_direction_third_part_y_vals = np.linspace(y_iter+0.4,  y_iter,     num_steps)
            z_direction_third_part_z_vals = np.linspace(z_iter+1.2,  z_iter+2,   num_steps)
            
            

            x_vals = np.concatenate((x_direction_first_part_x_vals, x_direction_second_part_x_vals, x_direction_third_part_x_vals, y_direction_first_part_x_vals, y_direction_second_part_x_vals, y_direction_third_part_x_vals, z_direction_first_part_x_vals, z_direction_second_part_x_vals, z_direction_third_part_x_vals))
            y_vals = np.concatenate((x_direction_first_part_y_vals, x_direction_second_part_y_vals, x_direction_third_part_y_vals, y_direction_first_part_y_vals, y_direction_second_part_y_vals, y_direction_third_part_y_vals, z_direction_first_part_y_vals, z_direction_second_part_y_vals, z_direction_third_part_y_vals))
            z_vals = np.concatenate((x_direction_first_part_z_vals, x_direction_second_part_z_vals, x_direction_third_part_z_vals, y_direction_first_part_z_vals, y_direction_second_part_z_vals, y_direction_third_part_z_vals, z_direction_first_part_z_vals, z_direction_second_part_z_vals, z_direction_third_part_z_vals))

            #Now there are 8 different components, so we draw them in 8 different colors. Each of them is a different translate.
            ax.scatter(x_vals, y_vals, z_vals, color='k')
            ax.scatter(x_vals+1, y_vals, z_vals, color='r')
            ax.scatter(x_vals, y_vals+1, z_vals, color='g')
            ax.scatter(x_vals+1, y_vals+1, z_vals, color='c')
            ax.scatter(x_vals, y_vals, z_vals+1, color='m')
            ax.scatter(x_vals+1, y_vals, z_vals+1, color='y')
            ax.scatter(x_vals, y_vals+1, z_vals+1, color='grey')
            ax.scatter(x_vals+1, y_vals+1, z_vals+1, color='b')

plt.show()
# Out:
# <div id='db3ec90f-e783-422a-8f52-f9b35785515e'></div>

# %%
#interwoven 3D grid with index 2*2*2, just one motif, as example point set to input in periodic persistence software:

num_steps = 15

fig = plt.figure(figsize=(12, 12))
ax = fig.add_subplot(projection='3d')

x_iter=0
y_iter=0
z_iter=0

x_direction_first_part_x_vals = np.linspace(x_iter+0.01, x_iter+0.3, num_steps) #I start a bit away from the end, so that no two points are identitcal.
x_direction_first_part_y_vals = np.linspace(y_iter,      y_iter+0.4, num_steps)
x_direction_first_part_z_vals = np.linspace(z_iter,      z_iter,     num_steps)

x_direction_second_part_x_vals = np.linspace(x_iter+0.3, x_iter+1.2, num_steps) 
x_direction_second_part_y_vals = np.linspace(y_iter+0.4, y_iter+0.2, num_steps)
x_direction_second_part_z_vals = np.linspace(z_iter,     z_iter+0.4, num_steps)

x_direction_third_part_x_vals = np.linspace(x_iter+1.2,  x_iter+1.99,num_steps) #I end a bit away from the end, so that no two points are identitcal.
x_direction_third_part_y_vals = np.linspace(y_iter+0.2,  y_iter,     num_steps)
x_direction_third_part_z_vals = np.linspace(z_iter+0.4,  z_iter,     num_steps)


y_direction_first_part_x_vals = np.linspace(x_iter,      x_iter,     num_steps) 
y_direction_first_part_y_vals = np.linspace(y_iter+0.01, y_iter+0.3, num_steps) #I start a bit away from the end, so that no two points are identitcal.
y_direction_first_part_z_vals = np.linspace(z_iter,      z_iter+0.4, num_steps)

y_direction_second_part_x_vals = np.linspace(x_iter,     x_iter+0.4, num_steps) 
y_direction_second_part_y_vals = np.linspace(y_iter+0.3, y_iter+1.2, num_steps)
y_direction_second_part_z_vals = np.linspace(z_iter+0.4, z_iter+0.2, num_steps)

y_direction_third_part_x_vals = np.linspace(x_iter+0.4,  x_iter,     num_steps) 
y_direction_third_part_y_vals = np.linspace(y_iter+1.2,  y_iter+1.99,num_steps) #I end a bit away from the end, so that no two points are identitcal.
y_direction_third_part_z_vals = np.linspace(z_iter+0.2,  z_iter,     num_steps)


z_direction_first_part_x_vals = np.linspace(x_iter,      x_iter+0.4, num_steps) 
z_direction_first_part_y_vals = np.linspace(y_iter,      y_iter,     num_steps)
z_direction_first_part_z_vals = np.linspace(z_iter+0.01, z_iter+0.3, num_steps) #I start a bit away from the end, so that no two points are identitcal.

z_direction_second_part_x_vals = np.linspace(x_iter+0.4, x_iter+0.2, num_steps) 
z_direction_second_part_y_vals = np.linspace(y_iter,     y_iter+0.4, num_steps)
z_direction_second_part_z_vals = np.linspace(z_iter+0.3, z_iter+1.2, num_steps)

z_direction_third_part_x_vals = np.linspace(x_iter+0.2,  x_iter,     num_steps) 
z_direction_third_part_y_vals = np.linspace(y_iter+0.4,  y_iter,     num_steps)
z_direction_third_part_z_vals = np.linspace(z_iter+1.2,  z_iter+1.99,num_steps) #I end a bit away from the end, so that no two points are identitcal.



x_vals = np.concatenate((x_direction_first_part_x_vals, x_direction_second_part_x_vals, x_direction_third_part_x_vals, y_direction_first_part_x_vals, y_direction_second_part_x_vals, y_direction_third_part_x_vals, z_direction_first_part_x_vals, z_direction_second_part_x_vals, z_direction_third_part_x_vals))
y_vals = np.concatenate((x_direction_first_part_y_vals, x_direction_second_part_y_vals, x_direction_third_part_y_vals, y_direction_first_part_y_vals, y_direction_second_part_y_vals, y_direction_third_part_y_vals, z_direction_first_part_y_vals, z_direction_second_part_y_vals, z_direction_third_part_y_vals))
z_vals = np.concatenate((x_direction_first_part_z_vals, x_direction_second_part_z_vals, x_direction_third_part_z_vals, y_direction_first_part_z_vals, y_direction_second_part_z_vals, y_direction_third_part_z_vals, z_direction_first_part_z_vals, z_direction_second_part_z_vals, z_direction_third_part_z_vals))


#To bring it into one unit cell (the unit cell is the standard 1x1x1 cubic unit cell)
x_vals = x_vals - np.floor(x_vals)
y_vals = y_vals - np.floor(y_vals) 
z_vals = z_vals - np.floor(z_vals)
 
ax.scatter(x_vals, y_vals, z_vals)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1200">
