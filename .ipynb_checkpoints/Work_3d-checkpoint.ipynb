# %%
# Pick convention: 
# We work on a rectangular cell of side lengths a, b, c
# This cuboid is in the positive coordinates and centered at 0
# I.e. spanned by (a,0,0), (0,b,0) and (0,0,c)

# %% [markdown]
# # Loading Packages

# %%
import numpy as np
import numpy.linalg as la
import sympy as sp
import random as rd
import gudhi as gd
import Simplex_Classes_3D as sc
import pph_examples as ex
from Reduce2IntegerBasis import reduce_spanning_set_3d as rss3
from copy import deepcopy
import matplotlib.pyplot as plt

# %% [markdown]
# # String formatting

# %%
bold0 = "\033[1m" # begin bold
bold1 = "\033[0m" # end bold

# %% [markdown]
# # Generating random points (optional)
#
# This function generates $N$ random points in a cell of sidelenghts $a,b,c$.
# This is for demonstration and testing, but not an integral part of the software.

# %%
def gen_points(N=5,a=1,b=1,c=1):
    """
    Generates N random points in [0,a]x[0,b]x[0,c] cuboid,
    outputts Nx3 numpy array, each row containing x, y,z coordinates of a point.
    """
    return np.array([[rd.random()*a, rd.random()*b, rd.random()*c] for i in range(N)])

# %% [markdown]
# # Creating periodic $\alpha$-filtration

# %% [markdown]
# ## Auxiliary functions for periodic_filtration()

# %% [markdown]
# ### Duplicating points to neighbouring cells
# Given points in a unit cell, this function duplicates them by translating to all neighbouring cells.
# This is an auxiliary step to calculating the _periodic_ $\alpha$-filtration.

# %%
def torus_copy(points, a=1,b=1,c=1):
    """
    Takes numpy array points of N points on axbxc cube
    and creates 8 copies surrounding it.
    
    Returns new_points, containing original points and 9+8+9=26 offset copies,
    so Nx27 points in total.
    """
    
    N = np.shape(points)[0]
    # first index  = which axbxc cuboid we are working on
    # second index = index of corresponding original point
    # third index  = x, y, z coordinates of point
    new_points = np.zeros((27,N,3)) 

    i = 0 # to index the cuboid
    for x in [-a,0,a]:
        for y in [-b,0,b]:
            for z in [-c,0,c]:
                transl = np.array([[x,y,z] for dummy in range(N)])
                new_points[i,:,:] = points + transl
                i += 1
            
    return new_points.reshape(-1,3)

# %% [markdown]
# ### Other functions

# %%
    def setup_unit_complex(points,max_alpha_square=float("inf"),a=1,b=1,c=1):
        """
        Setup for periodic_fitration() where the gudhi package is used
        to create an alpha filtration on the duplicated points. 
        """
        points_3x3x3 = torus_copy(points,a,b,c)
        
        # alpha-complex gets generation by gudhi
        alpha_complex = gd.AlphaComplex(points_3x3x3)
        simplex_tree = alpha_complex.create_simplex_tree(max_alpha_square=max_alpha_square)
        filtration = simplex_tree.get_filtration()   
        coords_cuboid = [alpha_complex.get_point(i) for i in range(len(points_3x3x3))]
        
        # SWITCH: axbxc --> 1x1x1
        coords_unit = [[x/a, y/b, z/c] for [x,y,z] in coords_cuboid]
        
        return coords_unit, filtration

# %%
def dim_split(filt):
    """
    Takes list of simplices 'filt' with filtration values, 
    i.e. with elements ([3,2], 0.123)
    Splits filt by dimension of elements.
    Outputs the 4 seperate lists, one for each dimension 0 to 3.
    """
    simps_split = [[] for i in range(4)]
    
    for (simp, val) in filt:
        p = len(simp)-1
        simps_split[p].append((simp,val))
        
    return simps_split[0], simps_split[1], simps_split[2], simps_split[3]

# %%
def check_bound(point):
    """
    Takes point with x,y,z coordinates.
    Checks if point lies in cuboid [0,1) x [0,1) x [0,1).
    If yes, outputs True, else False.
    """
    x = point[0]
    y = point[1]
    z = point[2]
    
    return (    x >= 0 and x < 1 
            and y >= 0 and y < 1 
            and z >= 0 and z < 1)

# %%
def equiv_num(x1,x2):
    """
    Calculates 'x1-x2 mod 1', where we always want to take 
    the representative with the smallest absolute value. 
    """
    z1 = abs((x1 - x2)%1)
    z2 = abs(z1 - 1)
    return min(z1,z2)

# %%
def identification_list(S0_list, S0, coords, eps = 1e-5):
    """
    Input:
        S0_list ... naive filtration list  of 0-simplices ([3],3) as given by gudhi
        S0      ... list of Simplex0D objects generated from S0

    Output:
        identify_list ... list of lists with entries [i,j], 
                           meaning that the ith vertex has to be matched to the jth Simplex0D object
    """
    # build identification list for later reference when building higher simplices
    identify_list = []
    
    """
    !
    This loop below could be made much more efficient!
    """

    for i in range(len(S0_list)):
        simp, filt_value = S0_list[i]
        coord = np.array(coords[i])

        for Simplex in S0: # looking for the point in the unit cell this corresponds to              
            other_coord = Simplex.coords

            if ((equiv_num(coord[0],other_coord[0])<eps) and 
                (equiv_num(coord[1],other_coord[1])<eps) and
                (equiv_num(coord[2],other_coord[2])<eps)):

                identify_index = Simplex.index_total

        identify_list.append([i, identify_index])
    return identify_list

# %%
def order_vertex(indices, coords):
    """
    Takes two vertices and outputs them by lexicographical order.
    
    Input:
        indices ... list [n0, n1], where ni is the integer filtration index of the ith vertex, identifying it uniquely 
        coords  ... list of lists [[x0, y0, z0], [x1, y1, z1]] containing the coordinates of both points.
        
    Output:
        [nl, nr]   ... list of indices in lexicographical order
        [xl,yl,zl] ... coordinates of left vertex
        [xr,yr,zl] ... coordinates of right vertex 
    
    """
    
    [n0, n1] = indices
    [x0, y0, z0] = np.around(coords[0],5)
    [x1, y1, z1] = np.around(coords[1],5)
    # we round to avoid ordering errors due to "same" being not the same
    
    
    if x0 < x1 or (x0 == x1 and y0 < y1) or (x0 == x1 and y0 == y1 and z0 < z1):
        # 0 is left
        left  = 0
        right = 1

    else:
        # 1 is left
        left  = 1
        right = 0
    
    # left vertex
    nl = indices[left]
    xl = coords[left][0]
    yl = coords[left][1]
    zl = coords[left][2]

    # right vertex
    nr = indices[right]
    xr = coords[right][0]
    yr = coords[right][1]
    zr = coords[right][2]
    return [nl, nr], [xl,yl,zl], [xr,yr,zr]

# %%
def crossing_vector(coord):
    """
    Takes coordinates coord=[x,y,z], which lie in unit_cube
    OR any of the 17 farther-right adjecent cells (up, up-right, right, low-right or low).
    
    Assumes that this coordinate corresponds to lexicographically second vertex of a 1-simplex and
    calculates respective crossing vector of 1-simplex. 
    """
   
    
    x = coord[0]
    y = coord[1]
    z = coord[2]
    
    dtype=np.int64
    vector = np.zeros(3,dtype=dtype)
    
    if x >= 1:
        vector += np.array([1,0,0],dtype=dtype)
    if y < 0 or y >= 1:
        vector += np.array([0,1,0],dtype=dtype) * int(np.sign(y))
    if z < 0 or z >= 1:
        vector += np.array([0,0,1],dtype=dtype) * int(np.sign(z))
    
    return np.array(vector)

# %% [markdown]
# ### Creation of Simplex objects

# %%
def create_S0(S0_list, coords):
    """
    Input:
        S0_list ... List of 0-simplices as generated by gudhi, 
        after having split them by dimension
    Output: 
        S0 ... List of Simplex0D objects containing the combinatorical representation,
        the integer filtration value, the continuous filtration value 
        and the geometric coordinate of the point
    """

    int_filt_value = 0
    S0 = []

    for i in range(len(S0_list)):
        simp, filt_value = S0_list[i]

        # check if 0-simplex lies in main cell
        coord = coords[i]
        if check_bound(coord): # point lies inside main cell
            S0.append(sc.Simplex0D([int_filt_value], 
                                            int_filt_value, 
                                            filt_value, 
                                            coord))
            int_filt_value +=1
    return S0

# %%
def create_S1(S1_list, S0, coords, identify_list):
    """
    Input: 
        Input:
        S1_list ... List of 1-simplices as generated by gudhi, 
        after having split them by dimension
        S0 ...List of Simplex0D objects of the filtration
        coords ... list of coordinates of vertices ordered by integer filtration value
        identify_list ... identification list for periodically copied points as given by identification_list()
        
    Output: 
        S1 ... List of Simplex1D objects containing the combinatorical representation,
        the integer filtration value, the continuous filtration value,
        the crossing vector as numpy array and the vertices constituting the boundary
        in lexicographical order
    """


    # note that this is not the actual integer filtration value 
    # and this will get corrected later on
    int_filt_value = len(S0) 
    S1 = []


    for i in range(len(S1_list)):
        simp, filt_value = S1_list[i]

        # check what the leftmost vertex is
        [n_left, n_right], coord_left, coord_right = order_vertex(simp, [coords[simp[0]], coords[simp[1]]])
        
        # Check if leftmost vertex is in unit cell
        if check_bound(coord_left):

            # Calculate crossing vector
            cross_vec = crossing_vector(coord_right)
            
            # identify the old vertices with the newly numerated ones!!!!! 
            # both for simplex, as well as for ordered vertices

            n_left_new  = (identify_list[n_left])[1]
            n_right_new = (identify_list[n_right])[1]

            int_ordered_simp = sorted([n_left_new,n_right_new])
            lex_ordered_simp = [S0[n_left_new], S0[n_right_new]]
            
            S1.append(sc.Simplex1D(int_ordered_simp, 
                                   int_filt_value, 
                                   filt_value, 
                                   cross_vec,
                                   lex_ordered_simp
                                  ))

            int_filt_value +=1
    return S1

# %%
def find_2Simplex_boundary(points,coords,S1, eps):
    """
    Input:
        points ... integer filtration values of vertices
        coords ... coordinates (in unit cell and its duplicates) of vertices
        S1     ... list of Simplex1D objects
        
    Output:
        bound_1, bound_2, bound_3 ... three Simplex1D objects from S1 which are formed by these points
    """
    
    """
    ! ! ! 
    This has not yet been adapted to 3D (shift only consideres x and y)
    I just included the z coordinate into the old code so that everything runs. 
    Make sure this is done correctly!!
    ! ! !
    """
    
    
    p1,p2,p3 = points
    p1_coord, p2_coord, p3_coord = coords
    
    # first boundary element from p1 to p2
    verts_1  = sorted([p1, p2])
    cv_1 = crossing_vector(p2_coord)

    # second boundary element from p1 to p3
    verts_2  = sorted([p1, p3])
    cv_2 = crossing_vector(p3_coord)

    # third boundary element from p2 to p3
    verts_3  = sorted([p2, p3])
    cv_3 = crossing_vector(p3_coord - crossing_vector(p2_coord))
    
    
    for j in range(len(S1)):
        
        Simplex = S1[j]
        verts = Simplex.verts
        cv    = Simplex.cv

            
        if (verts[0] == verts_1[0]) and (verts[1] == verts_1[1]) and (np.linalg.norm(cv-cv_1)<eps):
            bound_1 = Simplex
        if (verts[0] == verts_2[0]) and (verts[1] == verts_2[1]) and (np.linalg.norm(cv-cv_2)<eps):
            bound_2 = Simplex
        if (verts[0] == verts_3[0]) and (verts[1] == verts_3[1]) and (np.linalg.norm(cv-cv_3)<eps):
            bound_3 = Simplex
       
    return [bound_1, bound_2, bound_3]

# %%
def create_S2(S2_list, S1, S0, coords, identify_list, eps):
    """
    Input: 
        Input:
        S2_list ... List of 2-simplices as generated by gudhi, 
        after having split them by dimension
        S1 ... List of Simplex1D objects of the filtration
        coords ... list of coordinates of vertices ordered by integer filtration value
        identify_list ... identification list for periodically copied points as given by identification_list()
        
    Output: 
        S2 ... List of Simplex2D objects containing the combinatorical representation,
        the integer filtration value, the continuous filtration value,
        and the vertices constituting the boundary
        in lexicographical order
    """

    S2 = []
    int_filt_value = len(S0) + len(S1)
    for i in range(len(S2_list)):
        simp, filt_value = S2_list[i]

        # how can we find the correct 2-simplices?

        # if we have the vertices of the 2-simplex, we can look for 1-simplices which have two of these boundary points
        # since we only keep 2-simplices with their left-most point in the main cell
        # we can calculate the crossing vectors and then uniquly identify 2 out of 3 boundary elements

        # for the last edge, we have to 
        # - take the middle and the rightmost point,
        # - shift them such that the middle point is now in the main cell
        # - calculate the crossing vector of these shifted points
        # this is then the crossing vector of the last edge, and we can again identify
        # the correct 1-simplex using the vertices and the crossing vector


        # ordering vertices
        a0 = simp[0]
        b0 = simp[1]
        c0 = simp[2]
        a0_coord = coords[a0]
        b0_coord = coords[b0]
        c0_coord = coords[c0]

        [a1,b1], a1_coord, b1_coord = order_vertex([a0,b0], [a0_coord, b0_coord])
        [a2,c1], a2_coord, c1_coord = order_vertex([a1,c0], [a1_coord, c0_coord])
        [b2,c2], b2_coord, c2_coord = order_vertex([b1,c1], [b1_coord, c1_coord])

        # a2 is the leftmost, b2 is the middle and c2 is the rightmost coordinate, 
        # or a2 < b2 < c2 in lexicographical order


        # only if a2 is in the main cell do we continue
        if check_bound(a2_coord): 

            # the vertices are not yet in the naming convention we have chosen
            # so we rename them using identify_list
            for i in range(len(identify_list)):
                new_name = (identify_list[i])[1]
                if i == a2:
                    a2 = new_name
                if i == b2:
                    b2 = new_name
                if i == c2:
                    c2 = new_name


            bound_1, bound_2, bound_3 = find_2Simplex_boundary([a2,b2,c2],[a2_coord,b2_coord,c2_coord], S1, eps = eps)

            S2.append(sc.Simplex2D(sorted([a2,b2,c2]), 
                                   int_filt_value, 
                                   filt_value, 
                                   [S0[a2],S0[b2],S0[c2]], 
                                   [bound_1, bound_2, bound_3]))
            int_filt_value += 1
    return S2

# %%
def boundary4_from_rest(boundary1,boundary2,boundary3):
    """
    Given a 3-simplex, it has 4 boundary elements. 
    If we know 4 boundary 2-simplices, we can compare their respective edges.
    Collecting those that only show up for one 2-simplex each, 
    we can uniquly identify forth last 2-simplex by its boundary.
    """

    boundary4 = []
    # they each have one edge (1-simplex) which was not in the original list we searched for
    for edge in boundary1:
        if (edge not in boundary2) and (edge not in boundary3):
            boundary4.append(edge)

    for edge in boundary2:
        if (edge not in boundary1) and (edge not in boundary3):
            boundary4.append(edge)

    for edge in boundary3:
        if (edge not in boundary1) and (edge not in boundary2):
            boundary4.append(edge)
    return boundary4

# %%
def order_4_vertices(simp, coords):
    """
    Input:
        simp   ... 3-simplex constituted of 4 vertices, for example simp=[1,2,3,4]
        coords ... coordinates of the 4 vertices in the same order as in simp
    Ouptut:
        Integer filtration values and coordinates of the 4 points in 
        lexicographical order as dictated by their coordinates.
    """
    [n1, n2, n3, n4] = simp
    coord1 = coords[n1]
    coord2 = coords[n2]
    coord3 = coords[n3]
    coord4 = coords[n4]

    # ordering vertices
    a0 = n1
    b0 = n2
    c0 = n3
    d0 = n4
    a0_coord = coord1
    b0_coord = coord2
    c0_coord = coord3
    d0_coord = coord4

    [a1,b1], a1_coord, b1_coord = order_vertex([a0,b0], [a0_coord, b0_coord])
    [a2,c1], a2_coord, c1_coord = order_vertex([a1,c0], [a1_coord, c0_coord])
    [a3,d1], a3_coord, d1_coord = order_vertex([a2,d0], [a2_coord, d0_coord])
    # a3 is minimum
    [b2,c2], b2_coord, c2_coord = order_vertex([b1,c1], [b1_coord, c1_coord])
    [b3,d2], b3_coord, d2_coord = order_vertex([b2,d1], [b2_coord, d1_coord])
    # b3 is second smallest
    [c3,d3], c3_coord, d3_coord = order_vertex([c2,d2], [c2_coord, d2_coord])

    return a3,b3,c3,d3,a3_coord,b3_coord,c3_coord,d3_coord

# %%
def create_S3(S3_list, S2, S1, S0, coords, identify_list, eps):
    """
    Input: 
        Input:
        S3_list ... List of 3-simplices as generated by gudhi, 
        after having split them by dimension
        S2 ... List of Simplex1D objects of the filtration
        coords ... list of coordinates of vertices ordered by integer filtration value
        identify_list ... identification list for periodically copied points as given by identification_list()
        
    Output: 
        S3 ... List of Simplex3D objects containing the combinatorical representation,
        the integer filtration value, the continuous filtration value,
        and the edges constituting the boundary,
        and all vertices in lexicographical order
    """
    
    """
    !
    This code is just copied from S2.
    The code for S3 is not yet written (optional, since we don't need 3 simplices in my thesis) ...
    """
    
    
    S3 = []
    int_filt_value = len(S0) + len(S1) + len(S2)
    for i in range(len(S3_list)):
        simp, filt_value = S3_list[i] 
        
        a,b,c,d,a_coord,b_coord,c_coord,d_coord = order_4_vertices(simp, coords)
        
        # only if a3 is in the main cell do we continue
        if check_bound(a_coord): 
            
            # the vertices are not yet in the naming convention we have chosen
            # so we rename them using identify_list
           
            a = identify_list[a][1]
            b = identify_list[b][1]
            c = identify_list[c][1]
            d = identify_list[d][1]
            
            

            # we calculate 3 of the 6 1-simplices making up the 1-dim faces of our simplex
            boundary1 = find_2Simplex_boundary([a,b,c],[a_coord,b_coord,c_coord],S1, eps = eps)
            boundary2 = find_2Simplex_boundary([a,b,d],[a_coord,b_coord,d_coord],S1, eps = eps)
            boundary3 = find_2Simplex_boundary([a,c,d],[a_coord,c_coord,d_coord],S1, eps = eps)
            boundary4 = boundary4_from_rest(boundary1,boundary2,boundary3)


            # these edges form the last face
            # we now search for this last face

            # then we search for the 3 2-simplices that can be idenfified using these faces
            for simp2 in S2:
                S_bound = simp2.boundary
                if boundary1 == S_bound:
                    face1 = simp2
                elif boundary2 == S_bound:
                    face2 = simp2
                elif boundary3 == S_bound:
                    face3 = simp2
                elif boundary4 == S_bound:
                    face4 = simp2 
                    """
                    !
                    In this particular case, since boundary 4 is not outputted using the function we are used to
                    it might be that the == does not detect the permutation we have. 
                    !
                    """

            S3.append(sc.Simplex3D(sorted([a,b,c,d]), 
                                   int_filt_value, 
                                   filt_value, 
                                   [S0[a],S0[b],S0[c],S0[d]], 
                                   [face1,face2,face3,face4]
                                  )
                     )
            int_filt_value += 1
            del face1,face2,face3,face4
    return S3

# %% [markdown]
# ### Functions for generating the (correct) torus filtration

# %%
def generate_pfilt(S0,S1,S2,S3):
    """
    Takes the lists of simplex objects Si and generates the 
    mixed-dimension periodic filtration, so with all the simplices, but only saved
    through their vertices and their continuous filtration value.
    """
    
    """
    ! 
    This needs to be optimised / made prettier
    !
    """

    periodic_filt = []
    
    for simplices in [S0, S1, S2, S3]:
        periodic_filt += [(simplex.verts, simplex.index_cont) for simplex in simplices]

    periodic_filt.sort(key = lambda some_tuple: some_tuple[1])

    return periodic_filt

# %%
def reorder_by_cont(S0,S1,S2,S3,periodic_filt):
    """
    Since the integer filtration value is wrong (first storted by dimension, 
    only then by actuall filtration value), this needs to be reordered.
    This function takes the Simplex, looks where it is in the periodic filtration,
    and reassignes this placement. 
    """
    # if there are some simplices, which combinatorially are equal and which are born at the same time,
    # we need to pick an arbitrary order
    # so we replace in dummy_filt already picked elements with None
    dummy_filt = periodic_filt.copy()
    
    for simplices in [S0,S1,S2,S3]:
        update_index(simplices, dummy_filt)
    
def update_index(simplices, periodic_filt):
    for simplex in simplices:
        int_filt = periodic_filt.index((simplex.verts, simplex.index_cont))
        periodic_filt[int_filt] = None
        
        simplex.update_index_total(int_filt)

# %%
def calc_cc(simplex_objects):
    """
    Input:
        simplex_objects ... list of lists [S0,S1,S2,S3,S4] of all Simplex objects in periodic filtration
        
    No output. Changes the connected component attribute of all Simplex0D objects in S. 
    Hence if v is in S0, then v.component gets updated to the correct list of connected components at each time step.
    """
    N = sum([len(simplex_objects[i]) for i in range(4)]) # length of whole filtration
    N0 = len(simplex_objects[0])
    
    component_evolution = np.zeros((N0,N), dtype = np.int64)

    # from t=0 to t=N0-1 the vertices get born
    vertex_creation = [[-1 for t in range(vert)] + [vert for t in range(N0-vert)] for vert in range(N0)]
    # the -1 component is instead of None, because we are using a numpy array this time
    component_evolution[:,:N0] = vertex_creation
    
    last_t = N0-1
    for edge in simplex_objects[1]:
        t = edge.index_total
        v0_comp  = component_evolution[edge.vert0.index_total, last_t]
        v1_comp  = component_evolution[edge.vert1.index_total, last_t]
        dead_comp = max(v0_comp, v1_comp)
        life_comp = min(v0_comp, v1_comp)
        
        # fill up evolution up to and including t with most recent information
        for s in range(last_t+1,t+1):
            component_evolution[:,s] = component_evolution[:,s-1]
        
        if dead_comp != life_comp: # merger has happened
            for comp in range(N0):
                if component_evolution[comp, t] == dead_comp:
                    component_evolution[comp, t] = life_comp
                else:
                    component_evolution[comp, t] = component_evolution[comp, t-1]
        last_t = t
        
    for s in range(last_t+1,N):
        component_evolution[:,s] = component_evolution[:,s-1]
        
    for n in range(0,N0):
        comp_list = [None if x == -1 else x for x in component_evolution[n,:]]
        simplex_objects[0][n].create_cc(comp_list) # assign cc lists to vertices

# %% [markdown]
# ## Check legality of input data

# %%
def remove_duplicate_points(points):
    """
    Input: Nx3 numpy array
    Output: Mx3 numpy array, with all duplicate rows removed, hence M<N
    """
    # round inputs to 5 decimal places
    points = np.round(points, 5)
    return np.unique(points, axis = 0)

# %%
def check_domain(points, a, b, c):
    """
    Input: Nx3 numpy array, floats a,b,c
    Output: True if all points in array lie in [0,a)x[0,b)x[0,c)
    """
    in_domain = True
    for row in points:
        if (row[0] < 0) or (row[0] >= a):
            in_domain = False
            break
        elif (row[1] < 0) or (row[1] >= b):
            in_domain = False
            break
        elif (row[2] < 0) or (row[2] >= c):
            in_domain = False
            break
    return in_domain

# %%
def preprocess_points(points, a, b, c, eps = 1e-5):
    """
    Raise actual errors in this cases
    """
    if (not check_domain(points, a, b, c)):
        print("Some of the given points lie on the right boundary of the cell (have coordinate values x=a, y=b or c=c)")
        return
    
    points = remove_duplicate_points(points)
    
    # add noise in case the points are not in general position
    points += np.random.random((points.shape[0],3))*1e-3
    
    return points

# %% [markdown]
# ## The final periodic_filtration()

# %%
import time

    
def periodic_filtration(points, max_alpha_square=float("inf"), a=1, b=1, c=1):

    """
    Input:
        a, b, c            ... side lengths of cell [0,a) x [0,b) x [0,c)
        points             ... numpy array of size (N,3) containing N points in cell
        max_alpha_square   ... maximum alpha (squared) value of alpha-filtration
        
    Output:
        periodic_filt ... list of filtration elements of the form ([1,2,38],index_cont)
        S             ... list of lists [S0,S1,S2,S3], each sub-list containing all Simplex objects of given dimension
    """
   
    eps = 1e-5 # for identification purposes (rounding errors)
    
    
    
    points = preprocess_points(points, a, b, c, eps = eps)
    
    coords_unit, filtration = setup_unit_complex(points, max_alpha_square, a, b, c)
    
    # split unidentified simplices by dimension
    simp0, simp1, simp2, simp3 = dim_split(filtration)
    
    
    
    # 0-Simplices ---------------------------------
    S0 = create_S0(simp0, coords=coords_unit)
    identify_list = identification_list(S0_list=simp0, 
                                        S0=S0, 
                                        coords=coords_unit, 
                                        eps = eps)
    
    
    # 1-Simplices ---------------------------------
    S1 = create_S1(S1_list=simp1, 
                   S0=S0, 
                   coords=coords_unit, 
                   identify_list=identify_list) 
    
    # 2-Simplices ---------------------------------
    S2 = create_S2(S2_list=simp2, 
                   S1=S1, 
                   S0=S0, 
                   coords=coords_unit, 
                   identify_list=identify_list, 
                   eps = eps)
    
    
    # 3-Simplices
    S3 = create_S3(S3_list=simp3, 
                   S2=S2, 
                   S1=S1, 
                   S0=S0, 
                   coords=coords_unit, 
                   identify_list=identify_list, 
                   eps=eps) 

    
    
    """
    # !!!
    We need a comment about what this step does
    """
    periodic_filt = generate_pfilt(S0=S0, S1=S1, S2=S2, S3=S3)
    
    
    # re-assign correct integer filtration value
    reorder_by_cont(S0=S0,S1=S1,S2=S2,S3=S3, periodic_filt=periodic_filt)
    
    
    # rescaling to axbxc cuboid
    for simp in S0:
        simp.transf_coord(a,b,c)
    
    
    simplex_objects = [S0, S1, S2, S3]
    
    
    # Calculate connected components of 0 simplices
    calc_cc(simplex_objects)
    
    
    

    
    return periodic_filt, simplex_objects

# %% [markdown]
# ## TEST: periodic_filtration()

# %%
from importlib import reload  
sc = reload(sc)
#N = 8
a,b,c = 1,1,1
#points = gen_points(N,a,b,c)

points = np.array([
                   [0.2, 0.2, 0.4],
                   [0.2, 0.4, 0.2]])
N=len(points)

p_filt, simplex_objects = periodic_filtration(points,a=a,b=b,c=c)

# %% [markdown]
# # Calculating torus PH
#
# After the calculation of the periodic filtration, next comes calculating the periodic persistent homology. The algorithm here should not differ significantly from the standard ones. The only reason we are writing this from scratch is that pre-existing software is not made to handle our data, especialy in case of degenerate simplices.

# %% [markdown]
# ## Auxiliary functions for PH()

# %% [markdown]
# ### Classical PH algorithms

# %%
def boundary_matrix(simplex_objects):
    """
    Takes list of subslists of Simplix type objects.
    Outputs a boundary matrix as numpy matrix.
    
    Note that the boundary matrix is sorted by dimension (their index in S[i]), not as given by .index_total
    """
    S0, S1, S2, S3 = simplex_objects
    
    # Initialise matrix of dimension s0+s1+s2(boundaries) x s1+s2+s3
    D = np.zeros((len(S0+S1+S2),len(S0+S1+S2+S3)))
    
    # The 0-Simplices all appear at the beginning and are already ordered by their usual index
 
    
    d = [len(simplex_objects[i]) for i in range(4)]
    
    for j in range(d[1]):
        for i in S1[j].verts:
            D[i,j+d[0]] += 1
    
    for j in range(d[2]):
        for i in range(d[1]):
            if S1[i] in S2[j].boundary:
                D[i+d[0],j+d[0]+d[1]] += 1
                
    for j in range(d[3]):
        for i in range(d[2]):
            if S2[i] in S3[j].boundary:
                D[i+d[0]+d[1],j+d[0]+d[1]+d[2]] += 1
    
   
    
    return np.mod(D,2)

# %%
def check_low(column):
    """ 
    Takes a column i.e. numpy 1dim array. 
    Outputs the index of the lowest non-zero element of the given column.
    If the column is all zero, it returns -1.
    """
    low = -1
    m = len(column)
    for i in range(0,m):
        if column[m-1-i]==1:
            low = m-1-i
            break
    return low

# %%
def column_reduction(D, exhaustive=False): 
    """
    Takes a binary boundary matrix and performs column reduction on it.
    Returns the reduced matrix "R", as well as a list of its pivot elements "pivots". 
    Zero columns are encoded in pivots as -1. 
    """
    
    
    """
    # !!!!
    We want to implement exhaustive reduction at some point. 
    """
    # D is numpy array of size mxn
    (m,n) =  D.shape # rows, column
    R = D.copy()
    V = np.identity(n)
    
    pivots = []
    
    for i in range(0,n):
        # look at current pivot 
        low = check_low(R[:,i])
        
        # check if this is already a pivot element
        while (low in pivots) and (low != -1): 
            # while pivot is taken, perform matrix reduction on R
            
            j = pivots.index(low)
            R[:,i]= (R[:,i] + R[:,j]) % 2
            V[:,i]= (V[:,i] + V[:,j]) % 2
            
            # get new pivot
            low = check_low(R[:,i]) 
            
        pivots.append(low)
        
    
    return pivots, R, V

# %%
class TopologicalGroups:
    def __init__(self, dim=3):
        self.C = np.zeros(dim+1)
        self.Z = np.zeros(dim+1)
        self.B = np.zeros(dim+1)
        self.H = np.zeros(dim+1)
        self.dim = dim
        
    def calculate_group_dimensions(self, dim_list, pivots):
        m = 0
        for i in range(0,self.dim+1):
            # extract dimensions of vector spaces
            self.C[i]   = dim_list[i]
            self.Z[i]   = pivots[m:m+dim_list[i]].count(-1)
            self.B[i-1] = self.C[i] - self.Z[i]
            m += dim_list[i]

        for i in range(0,self.dim+1):
            self.H[i]   = self.Z[i] - self.B[i]

# %% [markdown]
# ### Persistence Pairs

# %%
def calculate_int_persistence_pairs(D, pivots, simplex_objects_flat):
    r"""
    Calculates persistence pairs with integer timestep values.
    Formatted such that it can be plotted by gudhi: (dim, (a,b))
    """
    
    integer_pairs = IntegerPersistenceIntervals()
    integer_pairs.calculate_integer_intervals(D, pivots, simplex_objects_flat)
    
    return integer_pairs




class IntegerPersistenceIntervals:
    def __init__(self):
        self.list = []
        
    def calculate_integer_intervals(self, D, pivots, simplex_objects_flat):
        # calculate persistence pairs
        for j in range(D.shape[1]): # looking at the jth column
            # determine dimension of new simplex associated to jth row
            dim = simplex_objects_flat[j].dim

            # if jth column = 0 --> new cycle
            if pivots[j] == -1:
                self.append_infinite_pair(dim, simplex_objects_flat[j])
                
            # if jth column != 0 --> death of homology class (that must have been born previously)
            else:
                self.replace_infinite_pair(dim, simplex_objects_flat[pivots[j]], simplex_objects_flat[j])
        
        # sort by beginning of interval
        self.list.sort(key=lambda l: (l[1])[0])


    def append_infinite_pair(self, dim, simplex):
        a = simplex.index_total
        self.list.append((dim, (a,float("inf"))))

    def replace_infinite_pair(self, dim, birth_simplex, death_simplex):
        a = birth_simplex.index_total
        b = death_simplex.index_total
        
        try:
            self.list.remove((dim-1, (a, float("inf"))))
        except ValueError:
            print(f'Pair {(dim-1, (a, float("inf")))} has not yet been added to pp_list and hence cannot be removed.')
        else:
            self.list.append((dim-1, (a,b)))

# %%
def create_persistence_pairs_list(integer_pairs, torus_filtration, V, simplex_objects):
    persistence_pairs = []
    
    for (dim,(a,b)) in integer_pairs.list:
        pair = sc.Persistence_Pair(dim, (a,b))
        pair.int2cont_interval(torus_filtration)
        if dim == 0 or dim == 1:
            pair.calc_birth_rep(V, simplex_objects)
            pair.calc_cc()
        persistence_pairs.append(pair)
    
    del pair
    
    """
    ! ! !
    The Code below was created because at every time step, either a new pair is 
    created or dies. This was not the case, so I had to investigate the timsteps.
    I will leave this in for now, but it should be removed.
    
    Replace the text here with an error in case a number is skipped
    """
    dummy_list_1 = [pair.lifespan_int[0] for pair in persistence_pairs]
    dummy_list_2 = [pair.lifespan_int[1] for pair in persistence_pairs]
    dummy_list = dummy_list_1 + dummy_list_2
    dummy_list.sort()
    
    boo = False
    for i in range(len(torus_filtration)):
        if i not in dummy_list:
            print("this number was skipped:")
            print(i)
            boo = True
            break
    if boo == True:
        print("Number was skipped")
        return
        
    """
    Here this ends ...
    """
        
    persistence_pairs.sort(key=lambda pair: pair.lifespan_int[0])
    return persistence_pairs

# %%
def generate_persistence_pairs(D, V, pivots, torus_filtration, simplex_objects):
    simplex_objects_flat =  [simp for sublist in simplex_objects for simp in sublist]
    
    integer_pairs = calculate_int_persistence_pairs(D, pivots, simplex_objects_flat)
    persistence_pairs  = create_persistence_pairs_list(integer_pairs, torus_filtration, V, simplex_objects)
  
    return persistence_pairs

# %% [markdown]
# ## The final PH()

# %%
def PH(torus_filtration, simplex_objects):
    """
    Takes list "torus_filtration" of naive torus filtration with continuous filtration values and
    list "simplex_objects" containing sublists of Simplex type objects, sorted by dimension.
    
    Returns the dimensions of Cn, Bn, Zn and Hn, 
    as well as persistence pairs "pp" and representatives "reps" of homology classes.
    """
    
    
    d=3 # this is the dimension we are working in
    
    D = boundary_matrix(simplex_objects)
    
    dim_list = [len(simplex_objects[i]) for i in range(0,d+1)]
    
    pivots, R, V = column_reduction(D)
    
    top_groups = TopologicalGroups()
    top_groups.calculate_group_dimensions(dim_list, pivots)
    
    persistence_pairs = generate_persistence_pairs(D, 
                                                   V, 
                                                   pivots, 
                                                   torus_filtration, 
                                                   simplex_objects)

    
    
    return top_groups, persistence_pairs

# %% [markdown]
# ## Plotting torus persistent pairs

# %%
def plot_persistence_pairs(persistence_pairs):
    pair_list = [(pair.dim, pair.lifespan_cont) for pair in persistence_pairs]
    gd.plot_persistence_diagram(pair_list)

# %% [markdown]
# ## TEST: PH()

# %%
from importlib import reload  
sc = reload(sc)
N = 10
a,b,c = 2,1,1
points = gen_points(N,a,b,c)
torus_filtration, simplex_objects = periodic_filtration(points,a=a,b=b,c=c)
#print()
top_groups, persistence_pairs = PH(torus_filtration, simplex_objects)
#print("\nBetti numbers")
#print(top_groups.H)
#plot_persistence_pairs(persistence_pairs)
# Out:
# [[0.03122 0.6873  0.2437 ]
#  [0.75229 0.87354 0.74005]
#  [0.76218 0.14588 0.25969]
#  [0.90699 0.42523 0.74865]
#  [1.44566 0.69408 0.18293]
#  [1.44862 0.18888 0.49836]
#  [1.5233  0.57583 0.00345]
#  [1.53705 0.47944 0.93875]
#  [1.69343 0.36281 0.85544]
#  [1.72842 0.19932 0.0737 ]]
# every number was covered

# %%
def int2cont(filtration):
    """
    Takes filtration in the gudhi style of 
    [([0], 0.0), ...]
    and extracts a dictionary, with keys being the index
    and the value being the corresponding continuous filtration value.
    """
    return {i: filtration[i][1] for i in range(len(filtration))}

# %% [markdown]
# # Calculating the evolution of $\Lambda_0$

# %% [markdown]
# ## Auxiliary functions for Lambda_0_evolution()

# %%
def vol_0d():
    return 1

def vol_1d(vector):
    return sp.Matrix(vector).norm()

def vol_2d(vector1, vector2):
    return sp.Matrix(vector1).cross(sp.Matrix(vector2)).norm()

def vol_3d(vector1, vector2, vector3):
    return sp.Matrix([vector1, vector2, vector3]).det()


def volume_pd(vector_matrix):
    r""" Takes list of p linearly independant vectors 
    and calculates the p-dimensional volume they span.
    
    """
    p = la.matrix_rank(vector_matrix)
    
    if p == 0:
        det_p = vol_0d()
    if p == 1:
        det_p = vol_1d(vector_matrix[:,0])
    if p == 2:
        det_p = vol_2d(vector_matrix[:,0], vector_matrix[:,1])
    if p == 3:
        det_p = vol_3d(vector_matrix[:,0], vector_matrix[:,1], vector_matrix[:,2])
    
    return abs(det_p), p

# %% [markdown]
# ## Event Types (Objects)

# %%
# these are the final object types that are outputted

class Merger:
    def __init__(self, timestep, old_comp, new_comp, cv_list, dim, det_abs, det_rel):
        self.time_index = timestep
        self.old_component = old_comp
        self.new_component = new_comp
        self.dim = dim
        self.det_abs = det_abs
        self.det_rel = det_rel 
        self.crossing_vector_list = cv_list
    
    
class StaticSublattice:
    def __init__(self, time, component, cv_list, basis_matrix, dim, det_abs, det_rel):
        self.time_index = time
        self.component = component
        self.crossing_vector_list = cv_list
        self.basis_matrix = basis_matrix
        self.dim = dim
        self.det_abs = det_abs
        self.det_rel = det_rel

# %% [markdown]
# ## Pair Addition

# %%
class PairAddition:
    def __init__(self, pair, time, trafo_matrix):
        self.pair = pair
        self.time_index = time
        self.trafo_matrix = trafo_matrix
        
        # dim 0
        self.dead_component = None
        self.surviving_component = None
        
        # dim 1
        self.component = None
        self.crossing_vector = None
        
        
        self.basis_matrix = None
        self.det_abs = None
        self.det_rel = None
        self.vector_dim = None
    
    
    def check_birth(self):
        """
        Returns True if persistence pair is born at self.time_index, otherwise returns False. 
        """
        return ((self.pair.dim == 1) and 
                (self.pair.lifespan_int[0] == self.time_index)
               )
    
    def check_death(self):
        """
        Returns True if persistence pair is born at time t, otherwise returns False. 
        """
        return ((self.pair.dim == 0) and 
                (self.pair.lifespan_int[1] == self.time_index)
               )
    def check_cv_nontrivial(self):
        """
        Returns True if (integer) vector is non-zero.
        """
        return abs(la.norm(self.crossing_vector)) > 0.9
    
    def generate_basis_matrix(self, crossing_vector_list):
        
        self.basis_matrix = np.zeros((3,3), dtype=np.int32)
        for i, vector in enumerate(crossing_vector_list):
            self.basis_matrix[:,i] = vector
            
        self.basis_matrix = np.dot(self.trafo_matrix, self.basis_matrix)
     
    
    def check_sublattice_change(self, last_event):
        """
        ! ! !
        here we might get floating point errors when compaing the determinants
        make this more foolproof
        """
        return (last_event.det_abs != self.det_abs or 
                last_event.dim != self.vector_dim
               )
    
    def cycle_birth(self, past_total_evolution):
        self.component = self.pair.component[self.time_index]
        self.crossing_vector = self.pair.calc_cv()

        if self.check_cv_nontrivial(): 
            old_crossing_vectors = past_total_evolution[self.component][-1].crossing_vector_list
            cv_list = rss3(old_crossing_vectors, self.crossing_vector)
            self.generate_basis_matrix(cv_list)
            self.det_abs, self.vector_dim = volume_pd(self.basis_matrix)
            self.det_rel = self.det_abs / la.det(self.trafo_matrix) 

            self.conditional_new_sublattice(past_total_evolution[self.component], cv_list)
            
            
    def component_death(self, past_total_evolution):
        self.dead_component = self.pair.component[self.time_index-1]
        self.surviving_component = self.pair.component[self.time_index]


        dead_comp_cvs = past_total_evolution[self.dead_component][-1].crossing_vector_list
        surviving_comp_cvs = past_total_evolution[self.surviving_component][-1].crossing_vector_list

        cv_list = surviving_comp_cvs.copy()

        for vec in dead_comp_cvs:
            cv_list = rss3(cv_list, vec)

        self.generate_basis_matrix(cv_list)
        self.det_abs, self.vector_dim = volume_pd(self.basis_matrix)
        self.det_rel = self.det_abs / la.det(self.trafo_matrix) 

        merger = Merger(self.time_index, 
                        self.dead_component, 
                        self.surviving_component, 
                        cv_list, 
                        self.vector_dim, 
                        self.det_abs, 
                        self.det_rel)

        past_total_evolution[self.dead_component].append(merger)
        past_total_evolution[self.surviving_component].append(merger)

        self.conditional_new_sublattice(past_total_evolution[self.surviving_component], cv_list)

        
    def add_pair(self, Lambda0_list):
        if self.check_birth():
            self.cycle_birth(Lambda0_list)

        
        elif self.check_death(): # 0-homology (connected component) dies
            self.component_death(Lambda0_list)

            
    def conditional_new_sublattice(self, past_comp_evolution, cv_list):
        if self.check_sublattice_change(past_comp_evolution[-1]):
            past_comp_evolution.append(StaticSublattice(self.time_index, 
                                                        self.component, 
                                                        cv_list, 
                                                        self.basis_matrix, 
                                                        self.vector_dim, 
                                                        self.det_abs, 
                                                        self.det_rel))

# %% [markdown]
# ## The final Lambda_0_evolution()

# %%
    
    
def Lambda_0_evolution(p_filt, N, persistence_pairs, trafo_matrix):
    """
    Takes filtration data (p_filt of torus filtration data, N number of initial vertices, 
    persistence_pairs and trafo_matrix dependent on initial cell) and returns Lambda0_list,
    which contains one sublist for each initial vertex (component), made up of Merger and 
    StaticSublattice objects, where each one corresponds to an event in the lifespan of that component. 
    """
    Lambda0_list = [[StaticSublattice(0, 
                                      component, 
                                      [], 
                                      np.zeros((3,3),dtype=np.int32), 
                                      0, 
                                      1, 
                                      1/la.det(trafo_matrix))] 
                    for component in range(N)]
    
                        
    for t in range(len(p_filt)):
        # search for pair that acts at time t
        for pair in persistence_pairs:
            pair_addition = PairAddition(pair, t, trafo_matrix)
            pair_addition.add_pair(Lambda0_list)
            
    return Lambda0_list

# %% [markdown]
# ## TEST:  Lambda_0_evolution()

# %%
from importlib import reload  
sc = reload(sc)
N = 5
a,b,c = 1,1,1
points = gen_points(N,a,b,c)

torus_filtration, simplex_objects = periodic_filtration(points,a=a,b=b,c=c)
print()
top_groups, persistence_pairs = PH(torus_filtration, simplex_objects)
print("\nBetti numbers")
print(top_groups.H)
plot_persistence_pairs(persistence_pairs)
print()
    
tic = time.perf_counter()  
trafo_matrix = np.diag([a,b,c])
evol = Lambda_0_evolution(torus_filtration, N, persistence_pairs, trafo_matrix);
toc = time.perf_counter()
print(f"Time of Lambda_0_evolution(): {toc - tic:0.4f}")
# Out:
# [[0.0674  0.12255 0.7264 ]
#  [0.34956 0.72614 0.35278]
#  [0.39433 0.81382 0.95612]
#  [0.70302 0.85015 0.28613]
#  [0.93555 0.3778  0.13642]]
#
# every number was covered
#
# Betti numbers
# [1. 3. 3. 1.]
#
# Time of Lambda_0_Evolution: 0.3182
# Time of Lambda_0_evolution(): 0.3185

# %% [markdown]
# # Creating Merge Tree

# %% [markdown]
# ## MergeOrder class for ordering branches

# %%
class MergeOrder:
    def __init__(self, data):
        self.data_static = deepcopy(data)
        self.data = deepcopy(data)
        self.R = [] # list of ordered indices
        self.current_branch_index = 0
        self.current_branch = self.data[0]
        
    def set_branch(self, index):
        self.current_branch_index = index
        self.current_branch = self.data[self.current_branch_index]
        
    def generate_order(self):
        self.data = deepcopy(self.data_static)
        self.set_branch(0)
        
        self.iterator()
        return self.R
    
    def iterator(self):
        # current branch
        merger_list = self.current_branch[:-1]
        if len(merger_list) == 0:
            self.R.append(self.current_branch_index)
            #print("R:",self.R)
            
            if self.current_branch_index != 0:
                mother_index = self.current_branch[-1].new_component
                # reached end of branch, switch to next branch on mother branch {mother_index}
                self.data[mother_index].pop(-2)
                self.set_branch(mother_index)
                self.iterator()
        else:
            # go deeper
            new_branch_index = merger_list[-1].old_component
            self.set_branch(new_branch_index)
            self.iterator()

# %% [markdown]
# ## Auxiliary functions

# %%
 
def colour_lookup():
    light_grey = '#e8e8e8' # dim = 0
    mid_grey   = '#bbbbbb' # dim = 1
    dark_grey  = '#5c5c5c' # dim = 2
    black      = '#000000' # dim = 3
    return {0: black,
            1: dark_grey,
            2: mid_grey,
            3: light_grey
           }

        
def extract_mergers_from_branch(branch):
    return [event for event in branch if type(event) == Merger]

def extract_sublattice_changes_from_branch(branch):
    return [event for event in branch if type(event) == StaticSublattice]
 
def extract_mergers_global(data):
    mergers = [extract_mergers_from_branch(branch) for branch in data]
    last_event_time = mergers[0][-1].time_index
    mergers[0].append(Merger(last_event_time + 2, 0, 0, None, None, None, None))
    return mergers

def extract_sublattice_changes_global(data):
    sublattice_changes = [extract_sublattice_changes_from_branch(branch) for branch in data]
    return sublattice_changes

def conditional_int2cont(time, continuous):
    if continuous is not None:
        time = continuous[time]
    return time

# %% [markdown]
# ## Plotting single branches

# %%
def plot_branch(component, ax, merge_data, data, order, continuous):
    x1 = order.index(component)
    x2 = order.index(merge_data[component][-1].new_component)
    
    
    if component == 0:
        age = data[component][-1].time_index + 1
    else:
        age = merge_data[component][-1].time_index
        
    age = conditional_int2cont(age, continuous)

    tick_length = 0.1
    total_height = conditional_int2cont(data[0][-1].time_index + 1, continuous)
    t0 = 0
    dim = 0
    det_rel = 1
    colour = colour_lookup()[0]
    for event in data[component]:
        
        # annotations
        if ((event.det_rel != det_rel) or (event.) 
            and isinstance(event, StaticSublattice)):
            event_time   = conditional_int2cont(event.time_index, continuous)
           
            # tick
            ax.plot([x1, x1+tick_length], [event_time, event_time], "black")
            # label
            ax.annotate(f"{event.det_rel} R^{dim}", (x1 + 3/2*tick_length, event_time))
            
            det_rel = event.det_rel
            
        # colour changes
        if ((event.dim != dim) or 
            (type(event) == Merger and event.old_component == component)
           ):
            event_time = conditional_int2cont(event.time_index, continuous)
            ax.plot([x1, x1], [t0, event_time], colour)
            dim = event.dim
            colour = colour_lookup()[dim]
            t0  = event_time
        
        

    ax.plot([x1, x1], [t0, age], colour_lookup()[dim])
    ax.plot([x1, x2], [age, age], colour)

# %% [markdown]
# ## plot_mergetree() function

# %%
def plot_mergetree(data, continuous = None, width=5, height=7):
    fig, ax = plt.subplots()
    
    merge_data = extract_mergers_global(data)
    order = MergeOrder(merge_data).generate_order()
    N = len(order)
    
    fig.set_size_inches(width, height)
    
    # create plot with vertical lines of correct lengths
    if continuous is None:
        ax.set_ylabel("timesteps (integer)") 
    else:
        ax.set_ylabel("timesteps (continuous)")
    ax.set_xlabel("component")
    yticks = [0]+[conditional_int2cont(merge_data[component][-1].time_index, continuous) for component in range(1,N)]
                      
    ax.set_xticks([i for i in range(N)])
    ax.set_xticklabels([str(comp) for comp in order])
    
    [ax.spines[edge].set_visible(False) for edge in ['top', 'bottom', 'right', 'left']]
    
    
    
    for component in range(N):
        plot_branch(component, ax, merge_data, data, order, continuous)

# %% [markdown]
# ## Testing plot_mergetree()

# %%
from importlib import reload  
sc = reload(sc)
N = 5
a,b,c = 1,1,1
points = gen_points(N,a,b,c)


torus_filtration, simplex_objects = periodic_filtration(points,a=a,b=b,c=c)
print()
top_groups, persistence_pairs = PH(torus_filtration, simplex_objects)
print("\nBetti numbers")
print(top_groups.H)
#plot_persistence_pairs(persistence_pairs)
print()
    
trafo_matrix = np.diag([a,b,c])
evol = Lambda_0_evolution(torus_filtration, N, persistence_pairs, trafo_matrix)
  
plot_mergetree(evol, continuous = int2cont(torus_filtration), width = 10, height = 15)
#plot_mergetree(evol, continuous = None, width = 10, height = 10)
# Out:
# every number was covered
#
# Betti numbers
# [1. 3. 3. 1.]
#
# Time of Lambda_0_Evolution: 0.1314

# %% [markdown]
# # Examples

# %% [markdown]
# ## Functions for Examples

# %%
class ExamplePrint:
    def __init__(self, points, a=1, b=1, c=1):
        self.points = points
        self.scale_x = a
        self.scale_y = b
        self.scale_z = c
        self.trafo_matrix = np.diag([a,b,c])
        self.N = len(points)
        
        self.groups = None
        self.pairs  = None
        self.evolution = None
        self.int2cont = None
        
    def calculate_pph(self):
        torus_filtration, simplex_objects = periodic_filtration(self.points,
                                                      a=self.scale_x,
                                                      b=self.scale_y,
                                                      c=self.scale_z)
        self.N = len(simplex_objects[0])
        self.int2cont = int2cont(torus_filtration)
        self.groups, self.pairs = PH(torus_filtration, simplex_objects)
        self.evolution = Lambda_0_evolution(torus_filtration, self.N, self.pairs, self.trafo_matrix);

        
    def describe_evolution(self):
        #plot_persistence_pairs(persistence_pairs)
        for comp in range(self.N):
            print("-------------------")
            print(f"{bold0}COMPONENT {comp}{bold1}")
            self.describe_component_evolution(comp)
            
            

    def describe_component_evolution(self, comp):
        for i in range(len(self.evolution[comp])):
            state = self.evolution[comp][i]
            if type(state) == StaticSublattice:
                print(f"""
{bold0}Timestep {state.time_index}{bold1}
dimension = {state.dim}
determinant = {float(state.det_abs):2.2f}
det. ratio  = {float(state.det_rel):2.2f}
basis = \n{state.basis_matrix}
cvs = \n{state.crossing_vector_list}
                """)
                
            elif type(state) == Merger:
                print(f"""
{bold0}Timestep {state.time_index}{bold1}
Component {state.old_component} merged to component {state.new_component}.
""")
   

    def plot_evolution(self, cont_timesteps = True, width=5, height=7):
        if cont_timesteps:
            plot_mergetree(self.evolution, 
                           continuous = self.int2cont, 
                           width=width, 
                           height=height)
        else:
            plot_mergetree(self.evolution, 
                           continuous = None, 
                           width=width, 
                           height=height)

# %% [markdown]
# # Run Examples

# %% [markdown]
# ## Example: Random points in axbxc cell

# %%
# random points example
N = 30
a,b,c = 1,1,1
#r_points = gen_points(N, a, b, c)
#random_example = ExamplePrint(r_points, a=a, b=b, c=c)
#random_example.calculate_pph()
#random_example.describe_evolution()
random_example.plot_evolution(cont_timesteps = True, width=20, height=20)

# %% [markdown]
# ## Example: Torus knot (p,q)

# %%
# torus knot example
p = 3
q = 1 # neq p
res = 30
t_points = ex.torus_knot(p=p, q=q, dim=3, res=res)
"""
! ! ! 
There is an error in the setting of p=15 and q=2 (res=30, I believe).
Check this out!!

! ! !
For  p=11, q=2, res=30, many components jump in dimension like this:
 0 -> 1 -> 0 -> 1
Should this be possible?
"""
#torus_knot_example = ExamplePrint(t_points, a=1, b=1, c=1)
#torus_knot_example.calculate_pph()
#torus_knot_example.describe_evolution()
torus_knot_example.plot_evolution(cont_timesteps = False, width = 11, height = 50)

# %% [markdown]
# ## Example: Teresa's interwoven grid (211)

# %%
# Teresa's interwoven grid
from importlib import reload  
ex = reload(ex)
# number of points is 5x num_steps
g211_points = ex.interwoven_grid_211(num_steps=5)

#teresas_example = ExamplePrint(g211_points, a=1, b=1, c=1)
#teresas_example.calculate_pph()
#teresas_example.describe_evolution()
teresas_example.plot_evolution(cont_timesteps = True, width=10, height=50)

# %% [markdown]
# ## Example: Teresa's interwoven grid (222)

# %%
# Teresa's interwoven grid
from importlib import reload  
ex = reload(ex)
# number of points is 9x num_steps
#g222_points = ex.interwoven_grid_222(num_steps=25)

#teresas_example_2 = ExamplePrint(g222_points, a=1, b=1, c=1)
#teresas_example_2.calculate_pph()
teresas_example_2.describe_evolution()
teresas_example_2.plot_evolution(cont_timesteps = True, width=10, height=10)
# Out:
# -------------------
# COMPONENT 0
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 229
# Component 28 merged to component 0.
#
#
# Timestep 247
# Component 35 merged to component 0.
#
#
# Timestep 249
# Component 27 merged to component 0.
#
#
# Timestep 251
# Component 33 merged to component 0.
#
#
# Timestep 286
# Component 42 merged to component 0.
#
#
# Timestep 288
# Component 68 merged to component 0.
#
#
# Timestep 291
# Component 41 merged to component 0.
#
#
# Timestep 292
# Component 1 merged to component 0.
#
#
# Timestep 293
# Component 73 merged to component 0.
#
#
# Timestep 294
# Component 75 merged to component 0.
#
#
# Timestep 296
# Component 116 merged to component 0.
#
#
# Timestep 299
# Component 12 merged to component 0.
#
#
# Timestep 300
# Component 24 merged to component 0.
#
#
# Timestep 303
# Component 137 merged to component 0.
#
#
# Timestep 306
# Component 154 merged to component 0.
#
#
# Timestep 309
# Component 128 merged to component 0.
#
#
# Timestep 310
# Component 222 merged to component 0.
#
#
# Timestep 330
# Component 221 merged to component 0.
#
#
# Timestep 331
# Component 26 merged to component 0.
#
#
# Timestep 332
# Component 31 merged to component 0.
#
#
# Timestep 372
# Component 217 merged to component 0.
#
#
# Timestep 381
# Component 29 merged to component 0.
#
#
# Timestep 387
# Component 38 merged to component 0.
#
#
# Timestep 392
# Component 40 merged to component 0.
#
#
# Timestep 394
# Component 58 merged to component 0.
#
#
# Timestep 403
# Component 213 merged to component 0.
#
#
# Timestep 404
# Component 86 merged to component 0.
#
#
# Timestep 409
# Component 107 merged to component 0.
#
#
# Timestep 410
# Component 46 merged to component 0.
#
#
# Timestep 426
# Component 184 merged to component 0.
#
#
# Timestep 433
# Component 131 merged to component 0.
#
#
# Timestep 445
# Component 163 merged to component 0.
#
#
# Timestep 456
# Component 111 merged to component 0.
#
#
# Timestep 462
# Component 176 merged to component 0.
#
#
# Timestep 465
# Component 218 merged to component 0.
#
#
# Timestep 469
# Component 93 merged to component 0.
#
#
# Timestep 472
# Component 76 merged to component 0.
#
#
# Timestep 473
# Component 211 merged to component 0.
#
#
# Timestep 478
# Component 115 merged to component 0.
#
#
# Timestep 480
# Component 47 merged to component 0.
#
#
# Timestep 481
# Component 135 merged to component 0.
#
#
# Timestep 482
# Component 166 merged to component 0.
#
#
# Timestep 486
# Component 155 merged to component 0.
#
#
# Timestep 487
# Component 197 merged to component 0.
#
#
# Timestep 488
# dimension = 1
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[1 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# [array([1, 0, 0], dtype=int32)]
#
#
# Timestep 489
# Component 78 merged to component 0.
#
#
# Timestep 490
# Component 167 merged to component 0.
#
#
# Timestep 491
# Component 158 merged to component 0.
#
#
# Timestep 492
# Component 207 merged to component 0.
#
#
# Timestep 494
# dimension = 2
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[1 0 0]
#  [0 0 0]
#  [0 1 0]]
# cvs =
# [array([1, 0, 0], dtype=int32), array([0, 0, 1], dtype=int32)]
#
#
# Timestep 495
# Component 44 merged to component 0.
#
#
# Timestep 496
# dimension = 3
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[1 0 0]
#  [0 0 1]
#  [0 1 0]]
# cvs =
# [array([1, 0, 0], dtype=int32), array([0, 0, 1], dtype=int32), array([0, 1, 0], dtype=int32)]
#
#
# Timestep 498
# Component 30 merged to component 0.
#
# -------------------
# COMPONENT 1
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 250
# Component 2 merged to component 1.
#
#
# Timestep 265
# Component 3 merged to component 1.
#
#
# Timestep 289
# Component 7 merged to component 1.
#
#
# Timestep 292
# Component 1 merged to component 0.
#
# -------------------
# COMPONENT 2
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 250
# Component 2 merged to component 1.
#
# -------------------
# COMPONENT 3
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 235
# Component 4 merged to component 3.
#
#
# Timestep 257
# Component 5 merged to component 3.
#
#
# Timestep 260
# Component 6 merged to component 3.
#
#
# Timestep 265
# Component 3 merged to component 1.
#
# -------------------
# COMPONENT 4
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 235
# Component 4 merged to component 3.
#
# -------------------
# COMPONENT 5
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 257
# Component 5 merged to component 3.
#
# -------------------
# COMPONENT 6
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 260
# Component 6 merged to component 3.
#
# -------------------
# COMPONENT 7
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 233
# Component 8 merged to component 7.
#
#
# Timestep 258
# Component 9 merged to component 7.
#
#
# Timestep 270
# Component 10 merged to component 7.
#
#
# Timestep 289
# Component 7 merged to component 1.
#
# -------------------
# COMPONENT 8
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 233
# Component 8 merged to component 7.
#
# -------------------
# COMPONENT 9
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 258
# Component 9 merged to component 7.
#
# -------------------
# COMPONENT 10
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 236
# Component 11 merged to component 10.
#
#
# Timestep 270
# Component 10 merged to component 7.
#
# -------------------
# COMPONENT 11
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 236
# Component 11 merged to component 10.
#
# -------------------
# COMPONENT 12
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 287
# Component 13 merged to component 12.
#
#
# Timestep 299
# Component 12 merged to component 0.
#
# -------------------
# COMPONENT 13
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 242
# Component 14 merged to component 13.
#
#
# Timestep 271
# Component 16 merged to component 13.
#
#
# Timestep 279
# Component 17 merged to component 13.
#
#
# Timestep 287
# Component 13 merged to component 12.
#
# -------------------
# COMPONENT 14
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 232
# Component 15 merged to component 14.
#
#
# Timestep 242
# Component 14 merged to component 13.
#
# -------------------
# COMPONENT 15
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 232
# Component 15 merged to component 14.
#
# -------------------
# COMPONENT 16
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 271
# Component 16 merged to component 13.
#
# -------------------
# COMPONENT 17
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 267
# Component 18 merged to component 17.
#
#
# Timestep 278
# Component 19 merged to component 17.
#
#
# Timestep 279
# Component 17 merged to component 13.
#
# -------------------
# COMPONENT 18
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 267
# Component 18 merged to component 17.
#
# -------------------
# COMPONENT 19
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 254
# Component 20 merged to component 19.
#
#
# Timestep 276
# Component 21 merged to component 19.
#
#
# Timestep 278
# Component 19 merged to component 17.
#
# -------------------
# COMPONENT 20
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 228
# Component 32 merged to component 20.
#
#
# Timestep 254
# Component 20 merged to component 19.
#
# -------------------
# COMPONENT 21
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 225
# Component 22 merged to component 21.
#
#
# Timestep 253
# Component 23 merged to component 21.
#
#
# Timestep 276
# Component 21 merged to component 19.
#
# -------------------
# COMPONENT 22
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 225
# Component 22 merged to component 21.
#
# -------------------
# COMPONENT 23
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 253
# Component 23 merged to component 21.
#
# -------------------
# COMPONENT 24
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 231
# Component 25 merged to component 24.
#
#
# Timestep 300
# Component 24 merged to component 0.
#
# -------------------
# COMPONENT 25
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 231
# Component 25 merged to component 24.
#
# -------------------
# COMPONENT 26
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 331
# Component 26 merged to component 0.
#
# -------------------
# COMPONENT 27
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 249
# Component 27 merged to component 0.
#
# -------------------
# COMPONENT 28
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 229
# Component 28 merged to component 0.
#
# -------------------
# COMPONENT 29
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 371
# Component 34 merged to component 29.
#
#
# Timestep 381
# Component 29 merged to component 0.
#
# -------------------
# COMPONENT 30
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 435
# Component 37 merged to component 30.
#
#
# Timestep 498
# Component 30 merged to component 0.
#
# -------------------
# COMPONENT 31
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 332
# Component 31 merged to component 0.
#
# -------------------
# COMPONENT 32
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 228
# Component 32 merged to component 20.
#
# -------------------
# COMPONENT 33
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 240
# Component 39 merged to component 33.
#
#
# Timestep 251
# Component 33 merged to component 0.
#
# -------------------
# COMPONENT 34
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 356
# Component 36 merged to component 34.
#
#
# Timestep 371
# Component 34 merged to component 29.
#
# -------------------
# COMPONENT 35
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 247
# Component 35 merged to component 0.
#
# -------------------
# COMPONENT 36
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 356
# Component 36 merged to component 34.
#
# -------------------
# COMPONENT 37
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 435
# Component 37 merged to component 30.
#
# -------------------
# COMPONENT 38
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 370
# Component 45 merged to component 38.
#
#
# Timestep 387
# Component 38 merged to component 0.
#
# -------------------
# COMPONENT 39
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 240
# Component 39 merged to component 33.
#
# -------------------
# COMPONENT 40
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 339
# Component 43 merged to component 40.
#
#
# Timestep 392
# Component 40 merged to component 0.
#
# -------------------
# COMPONENT 41
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 269
# Component 49 merged to component 41.
#
#
# Timestep 272
# Component 55 merged to component 41.
#
#
# Timestep 280
# Component 69 merged to component 41.
#
#
# Timestep 291
# Component 41 merged to component 0.
#
# -------------------
# COMPONENT 42
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 285
# Component 48 merged to component 42.
#
#
# Timestep 286
# Component 42 merged to component 0.
#
# -------------------
# COMPONENT 43
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 339
# Component 43 merged to component 40.
#
# -------------------
# COMPONENT 44
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 421
# Component 51 merged to component 44.
#
#
# Timestep 493
# Component 57 merged to component 44.
#
#
# Timestep 495
# Component 44 merged to component 0.
#
# -------------------
# COMPONENT 45
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 362
# Component 52 merged to component 45.
#
#
# Timestep 370
# Component 45 merged to component 38.
#
# -------------------
# COMPONENT 46
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 360
# Component 50 merged to component 46.
#
#
# Timestep 389
# Component 54 merged to component 46.
#
#
# Timestep 405
# Component 67 merged to component 46.
#
#
# Timestep 407
# Component 104 merged to component 46.
#
#
# Timestep 410
# Component 46 merged to component 0.
#
# -------------------
# COMPONENT 47
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 427
# Component 61 merged to component 47.
#
#
# Timestep 480
# Component 47 merged to component 0.
#
# -------------------
# COMPONENT 48
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 284
# Component 53 merged to component 48.
#
#
# Timestep 285
# Component 48 merged to component 42.
#
# -------------------
# COMPONENT 49
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 269
# Component 49 merged to component 41.
#
# -------------------
# COMPONENT 50
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 360
# Component 50 merged to component 46.
#
# -------------------
# COMPONENT 51
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 421
# Component 51 merged to component 44.
#
# -------------------
# COMPONENT 52
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 362
# Component 52 merged to component 45.
#
# -------------------
# COMPONENT 53
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 226
# Component 59 merged to component 53.
#
#
# Timestep 261
# Component 63 merged to component 53.
#
#
# Timestep 284
# Component 53 merged to component 48.
#
# -------------------
# COMPONENT 54
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 359
# Component 56 merged to component 54.
#
#
# Timestep 389
# Component 54 merged to component 46.
#
# -------------------
# COMPONENT 55
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 227
# Component 62 merged to component 55.
#
#
# Timestep 272
# Component 55 merged to component 41.
#
# -------------------
# COMPONENT 56
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 343
# Component 60 merged to component 56.
#
#
# Timestep 354
# Component 64 merged to component 56.
#
#
# Timestep 359
# Component 56 merged to component 54.
#
# -------------------
# COMPONENT 57
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 425
# Component 65 merged to component 57.
#
#
# Timestep 477
# Component 71 merged to component 57.
#
#
# Timestep 493
# Component 57 merged to component 44.
#
# -------------------
# COMPONENT 58
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 386
# Component 66 merged to component 58.
#
#
# Timestep 394
# Component 58 merged to component 0.
#
# -------------------
# COMPONENT 59
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 226
# Component 59 merged to component 53.
#
# -------------------
# COMPONENT 60
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 343
# Component 60 merged to component 56.
#
# -------------------
# COMPONENT 61
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 427
# Component 61 merged to component 47.
#
# -------------------
# COMPONENT 62
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 227
# Component 62 merged to component 55.
#
# -------------------
# COMPONENT 63
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 261
# Component 63 merged to component 53.
#
# -------------------
# COMPONENT 64
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 354
# Component 64 merged to component 56.
#
# -------------------
# COMPONENT 65
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 425
# Component 65 merged to component 57.
#
# -------------------
# COMPONENT 66
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 337
# Component 72 merged to component 66.
#
#
# Timestep 364
# Component 79 merged to component 66.
#
#
# Timestep 386
# Component 66 merged to component 58.
#
# -------------------
# COMPONENT 67
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 348
# Component 70 merged to component 67.
#
#
# Timestep 402
# Component 74 merged to component 67.
#
#
# Timestep 405
# Component 67 merged to component 46.
#
# -------------------
# COMPONENT 68
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 288
# Component 68 merged to component 0.
#
# -------------------
# COMPONENT 69
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 280
# Component 69 merged to component 41.
#
# -------------------
# COMPONENT 70
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 348
# Component 70 merged to component 67.
#
# -------------------
# COMPONENT 71
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 477
# Component 71 merged to component 57.
#
# -------------------
# COMPONENT 72
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 337
# Component 72 merged to component 66.
#
# -------------------
# COMPONENT 73
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 234
# Component 80 merged to component 73.
#
#
# Timestep 246
# Component 83 merged to component 73.
#
#
# Timestep 252
# Component 88 merged to component 73.
#
#
# Timestep 281
# Component 94 merged to component 73.
#
#
# Timestep 290
# Component 141 merged to component 73.
#
#
# Timestep 293
# Component 73 merged to component 0.
#
# -------------------
# COMPONENT 74
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 341
# Component 77 merged to component 74.
#
#
# Timestep 395
# Component 81 merged to component 74.
#
#
# Timestep 396
# Component 90 merged to component 74.
#
#
# Timestep 402
# Component 74 merged to component 67.
#
# -------------------
# COMPONENT 75
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 243
# Component 82 merged to component 75.
#
#
# Timestep 245
# Component 89 merged to component 75.
#
#
# Timestep 282
# Component 96 merged to component 75.
#
#
# Timestep 294
# Component 75 merged to component 0.
#
# -------------------
# COMPONENT 76
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 472
# Component 76 merged to component 0.
#
# -------------------
# COMPONENT 77
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 341
# Component 77 merged to component 74.
#
# -------------------
# COMPONENT 78
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 451
# Component 85 merged to component 78.
#
#
# Timestep 454
# Component 91 merged to component 78.
#
#
# Timestep 470
# Component 99 merged to component 78.
#
#
# Timestep 474
# Component 106 merged to component 78.
#
#
# Timestep 475
# Component 133 merged to component 78.
#
#
# Timestep 489
# Component 78 merged to component 0.
#
# -------------------
# COMPONENT 79
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 364
# Component 79 merged to component 66.
#
# -------------------
# COMPONENT 80
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 234
# Component 80 merged to component 73.
#
# -------------------
# COMPONENT 81
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 353
# Component 84 merged to component 81.
#
#
# Timestep 376
# Component 87 merged to component 81.
#
#
# Timestep 395
# Component 81 merged to component 74.
#
# -------------------
# COMPONENT 82
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 243
# Component 82 merged to component 75.
#
# -------------------
# COMPONENT 83
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 246
# Component 83 merged to component 73.
#
# -------------------
# COMPONENT 84
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 353
# Component 84 merged to component 81.
#
# -------------------
# COMPONENT 85
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 451
# Component 85 merged to component 78.
#
# -------------------
# COMPONENT 86
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 374
# Component 92 merged to component 86.
#
#
# Timestep 391
# Component 105 merged to component 86.
#
#
# Timestep 399
# Component 171 merged to component 86.
#
#
# Timestep 404
# Component 86 merged to component 0.
#
# -------------------
# COMPONENT 87
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 376
# Component 87 merged to component 81.
#
# -------------------
# COMPONENT 88
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 252
# Component 88 merged to component 73.
#
# -------------------
# COMPONENT 89
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 245
# Component 89 merged to component 75.
#
# -------------------
# COMPONENT 90
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 365
# Component 95 merged to component 90.
#
#
# Timestep 369
# Component 97 merged to component 90.
#
#
# Timestep 396
# Component 90 merged to component 74.
#
# -------------------
# COMPONENT 91
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 454
# Component 91 merged to component 78.
#
# -------------------
# COMPONENT 92
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 346
# Component 98 merged to component 92.
#
#
# Timestep 374
# Component 92 merged to component 86.
#
# -------------------
# COMPONENT 93
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 469
# Component 93 merged to component 0.
#
# -------------------
# COMPONENT 94
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 266
# Component 100 merged to component 94.
#
#
# Timestep 268
# Component 103 merged to component 94.
#
#
# Timestep 275
# Component 114 merged to component 94.
#
#
# Timestep 281
# Component 94 merged to component 73.
#
# -------------------
# COMPONENT 95
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 365
# Component 95 merged to component 90.
#
# -------------------
# COMPONENT 96
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 237
# Component 102 merged to component 96.
#
#
# Timestep 256
# Component 110 merged to component 96.
#
#
# Timestep 282
# Component 96 merged to component 75.
#
# -------------------
# COMPONENT 97
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 335
# Component 101 merged to component 97.
#
#
# Timestep 369
# Component 97 merged to component 90.
#
# -------------------
# COMPONENT 98
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 346
# Component 98 merged to component 92.
#
# -------------------
# COMPONENT 99
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 470
# Component 99 merged to component 78.
#
# -------------------
# COMPONENT 100
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 266
# Component 100 merged to component 94.
#
# -------------------
# COMPONENT 101
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 335
# Component 101 merged to component 97.
#
# -------------------
# COMPONENT 102
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 237
# Component 102 merged to component 96.
#
# -------------------
# COMPONENT 103
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 241
# Component 109 merged to component 103.
#
#
# Timestep 268
# Component 103 merged to component 94.
#
# -------------------
# COMPONENT 104
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 350
# Component 108 merged to component 104.
#
#
# Timestep 407
# Component 104 merged to component 46.
#
# -------------------
# COMPONENT 105
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 352
# Component 112 merged to component 105.
#
#
# Timestep 366
# Component 118 merged to component 105.
#
#
# Timestep 390
# Component 126 merged to component 105.
#
#
# Timestep 391
# Component 105 merged to component 86.
#
# -------------------
# COMPONENT 106
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 440
# Component 113 merged to component 106.
#
#
# Timestep 441
# Component 119 merged to component 106.
#
#
# Timestep 444
# Component 127 merged to component 106.
#
#
# Timestep 474
# Component 106 merged to component 78.
#
# -------------------
# COMPONENT 107
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 334
# Component 121 merged to component 107.
#
#
# Timestep 406
# Component 134 merged to component 107.
#
#
# Timestep 408
# Component 196 merged to component 107.
#
#
# Timestep 409
# Component 107 merged to component 0.
#
# -------------------
# COMPONENT 108
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 350
# Component 108 merged to component 104.
#
# -------------------
# COMPONENT 109
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 241
# Component 109 merged to component 103.
#
# -------------------
# COMPONENT 110
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 256
# Component 110 merged to component 96.
#
# -------------------
# COMPONENT 111
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 456
# Component 111 merged to component 0.
#
# -------------------
# COMPONENT 112
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 352
# Component 112 merged to component 105.
#
# -------------------
# COMPONENT 113
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 440
# Component 113 merged to component 106.
#
# -------------------
# COMPONENT 114
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 239
# Component 120 merged to component 114.
#
#
# Timestep 273
# Component 124 merged to component 114.
#
#
# Timestep 274
# Component 125 merged to component 114.
#
#
# Timestep 275
# Component 114 merged to component 94.
#
# -------------------
# COMPONENT 115
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 424
# Component 117 merged to component 115.
#
#
# Timestep 471
# Component 122 merged to component 115.
#
#
# Timestep 478
# Component 115 merged to component 0.
#
# -------------------
# COMPONENT 116
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 223
# Component 123 merged to component 116.
#
#
# Timestep 255
# Component 130 merged to component 116.
#
#
# Timestep 296
# Component 116 merged to component 0.
#
# -------------------
# COMPONENT 117
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 424
# Component 117 merged to component 115.
#
# -------------------
# COMPONENT 118
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 366
# Component 118 merged to component 105.
#
# -------------------
# COMPONENT 119
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 441
# Component 119 merged to component 106.
#
# -------------------
# COMPONENT 120
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 239
# Component 120 merged to component 114.
#
# -------------------
# COMPONENT 121
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 334
# Component 121 merged to component 107.
#
# -------------------
# COMPONENT 122
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 471
# Component 122 merged to component 115.
#
# -------------------
# COMPONENT 123
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 223
# Component 123 merged to component 116.
#
# -------------------
# COMPONENT 124
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 262
# Component 129 merged to component 124.
#
#
# Timestep 263
# Component 136 merged to component 124.
#
#
# Timestep 273
# Component 124 merged to component 114.
#
# -------------------
# COMPONENT 125
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 274
# Component 125 merged to component 114.
#
# -------------------
# COMPONENT 126
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 385
# Component 132 merged to component 126.
#
#
# Timestep 390
# Component 126 merged to component 105.
#
# -------------------
# COMPONENT 127
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 444
# Component 127 merged to component 106.
#
# -------------------
# COMPONENT 128
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 309
# Component 128 merged to component 0.
#
# -------------------
# COMPONENT 129
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 262
# Component 129 merged to component 124.
#
# -------------------
# COMPONENT 130
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 255
# Component 130 merged to component 116.
#
# -------------------
# COMPONENT 131
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 433
# Component 131 merged to component 0.
#
# -------------------
# COMPONENT 132
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 367
# Component 139 merged to component 132.
#
#
# Timestep 368
# Component 159 merged to component 132.
#
#
# Timestep 385
# Component 132 merged to component 126.
#
# -------------------
# COMPONENT 133
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 453
# Component 140 merged to component 133.
#
#
# Timestep 468
# Component 147 merged to component 133.
#
#
# Timestep 475
# Component 133 merged to component 78.
#
# -------------------
# COMPONENT 134
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 351
# Component 148 merged to component 134.
#
#
# Timestep 393
# Component 161 merged to component 134.
#
#
# Timestep 397
# Component 189 merged to component 134.
#
#
# Timestep 400
# Component 193 merged to component 134.
#
#
# Timestep 406
# Component 134 merged to component 107.
#
# -------------------
# COMPONENT 135
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 455
# Component 138 merged to component 135.
#
#
# Timestep 458
# Component 142 merged to component 135.
#
#
# Timestep 463
# Component 144 merged to component 135.
#
#
# Timestep 481
# Component 135 merged to component 0.
#
# -------------------
# COMPONENT 136
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 263
# Component 136 merged to component 124.
#
# -------------------
# COMPONENT 137
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 248
# Component 143 merged to component 137.
#
#
# Timestep 259
# Component 151 merged to component 137.
#
#
# Timestep 295
# Component 162 merged to component 137.
#
#
# Timestep 297
# Component 186 merged to component 137.
#
#
# Timestep 301
# Component 157 merged to component 137.
#
#
# Timestep 303
# Component 137 merged to component 0.
#
# -------------------
# COMPONENT 138
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 455
# Component 138 merged to component 135.
#
# -------------------
# COMPONENT 139
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 358
# Component 146 merged to component 139.
#
#
# Timestep 363
# Component 153 merged to component 139.
#
#
# Timestep 367
# Component 139 merged to component 132.
#
# -------------------
# COMPONENT 140
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 453
# Component 140 merged to component 133.
#
# -------------------
# COMPONENT 141
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 238
# Component 145 merged to component 141.
#
#
# Timestep 264
# Component 150 merged to component 141.
#
#
# Timestep 290
# Component 141 merged to component 73.
#
# -------------------
# COMPONENT 142
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 458
# Component 142 merged to component 135.
#
# -------------------
# COMPONENT 143
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 248
# Component 143 merged to component 137.
#
# -------------------
# COMPONENT 144
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 447
# Component 149 merged to component 144.
#
#
# Timestep 463
# Component 144 merged to component 135.
#
# -------------------
# COMPONENT 145
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 238
# Component 145 merged to component 141.
#
# -------------------
# COMPONENT 146
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 358
# Component 146 merged to component 139.
#
# -------------------
# COMPONENT 147
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 468
# Component 147 merged to component 133.
#
# -------------------
# COMPONENT 148
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 351
# Component 148 merged to component 134.
#
# -------------------
# COMPONENT 149
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 446
# Component 152 merged to component 149.
#
#
# Timestep 447
# Component 149 merged to component 144.
#
# -------------------
# COMPONENT 150
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 264
# Component 150 merged to component 141.
#
# -------------------
# COMPONENT 151
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 230
# Component 156 merged to component 151.
#
#
# Timestep 259
# Component 151 merged to component 137.
#
# -------------------
# COMPONENT 152
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 446
# Component 152 merged to component 149.
#
# -------------------
# COMPONENT 153
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 363
# Component 153 merged to component 139.
#
# -------------------
# COMPONENT 154
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 306
# Component 154 merged to component 0.
#
# -------------------
# COMPONENT 155
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 486
# Component 155 merged to component 0.
#
# -------------------
# COMPONENT 156
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 230
# Component 156 merged to component 151.
#
# -------------------
# COMPONENT 157
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 301
# Component 157 merged to component 137.
#
# -------------------
# COMPONENT 158
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 422
# Component 160 merged to component 158.
#
#
# Timestep 479
# Component 164 merged to component 158.
#
#
# Timestep 491
# Component 158 merged to component 0.
#
# -------------------
# COMPONENT 159
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 345
# Component 165 merged to component 159.
#
#
# Timestep 368
# Component 159 merged to component 132.
#
# -------------------
# COMPONENT 160
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 422
# Component 160 merged to component 158.
#
# -------------------
# COMPONENT 161
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 357
# Component 173 merged to component 161.
#
#
# Timestep 388
# Component 185 merged to component 161.
#
#
# Timestep 393
# Component 161 merged to component 134.
#
# -------------------
# COMPONENT 162
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 244
# Component 168 merged to component 162.
#
#
# Timestep 283
# Component 174 merged to component 162.
#
#
# Timestep 295
# Component 162 merged to component 137.
#
# -------------------
# COMPONENT 163
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 438
# Component 169 merged to component 163.
#
#
# Timestep 445
# Component 163 merged to component 0.
#
# -------------------
# COMPONENT 164
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 479
# Component 164 merged to component 158.
#
# -------------------
# COMPONENT 165
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 345
# Component 165 merged to component 159.
#
# -------------------
# COMPONENT 166
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 432
# Component 178 merged to component 166.
#
#
# Timestep 448
# Component 188 merged to component 166.
#
#
# Timestep 476
# Component 190 merged to component 166.
#
#
# Timestep 482
# Component 166 merged to component 0.
#
# -------------------
# COMPONENT 167
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 428
# Component 170 merged to component 167.
#
#
# Timestep 464
# Component 172 merged to component 167.
#
#
# Timestep 466
# Component 175 merged to component 167.
#
#
# Timestep 485
# Component 179 merged to component 167.
#
#
# Timestep 490
# Component 167 merged to component 0.
#
# -------------------
# COMPONENT 168
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 244
# Component 168 merged to component 162.
#
# -------------------
# COMPONENT 169
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 438
# Component 169 merged to component 163.
#
# -------------------
# COMPONENT 170
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 428
# Component 170 merged to component 167.
#
# -------------------
# COMPONENT 171
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 361
# Component 177 merged to component 171.
#
#
# Timestep 377
# Component 183 merged to component 171.
#
#
# Timestep 382
# Component 187 merged to component 171.
#
#
# Timestep 399
# Component 171 merged to component 86.
#
# -------------------
# COMPONENT 172
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 464
# Component 172 merged to component 167.
#
# -------------------
# COMPONENT 173
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 357
# Component 173 merged to component 161.
#
# -------------------
# COMPONENT 174
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 224
# Component 180 merged to component 174.
#
#
# Timestep 283
# Component 174 merged to component 162.
#
# -------------------
# COMPONENT 175
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 466
# Component 175 merged to component 167.
#
# -------------------
# COMPONENT 176
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 459
# Component 182 merged to component 176.
#
#
# Timestep 462
# Component 176 merged to component 0.
#
# -------------------
# COMPONENT 177
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 361
# Component 177 merged to component 171.
#
# -------------------
# COMPONENT 178
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 432
# Component 178 merged to component 166.
#
# -------------------
# COMPONENT 179
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 431
# Component 181 merged to component 179.
#
#
# Timestep 485
# Component 179 merged to component 167.
#
# -------------------
# COMPONENT 180
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 224
# Component 180 merged to component 174.
#
# -------------------
# COMPONENT 181
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 431
# Component 181 merged to component 179.
#
# -------------------
# COMPONENT 182
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 459
# Component 182 merged to component 176.
#
# -------------------
# COMPONENT 183
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 377
# Component 183 merged to component 171.
#
# -------------------
# COMPONENT 184
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 426
# Component 184 merged to component 0.
#
# -------------------
# COMPONENT 185
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 388
# Component 185 merged to component 161.
#
# -------------------
# COMPONENT 186
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 297
# Component 186 merged to component 137.
#
# -------------------
# COMPONENT 187
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 382
# Component 187 merged to component 171.
#
# -------------------
# COMPONENT 188
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 448
# Component 188 merged to component 166.
#
# -------------------
# COMPONENT 189
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 333
# Component 191 merged to component 189.
#
#
# Timestep 397
# Component 189 merged to component 134.
#
# -------------------
# COMPONENT 190
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 457
# Component 192 merged to component 190.
#
#
# Timestep 476
# Component 190 merged to component 166.
#
# -------------------
# COMPONENT 191
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 333
# Component 191 merged to component 189.
#
# -------------------
# COMPONENT 192
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 439
# Component 194 merged to component 192.
#
#
# Timestep 457
# Component 192 merged to component 190.
#
# -------------------
# COMPONENT 193
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 378
# Component 195 merged to component 193.
#
#
# Timestep 400
# Component 193 merged to component 134.
#
# -------------------
# COMPONENT 194
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 439
# Component 194 merged to component 192.
#
# -------------------
# COMPONENT 195
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 378
# Component 195 merged to component 193.
#
# -------------------
# COMPONENT 196
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 355
# Component 198 merged to component 196.
#
#
# Timestep 384
# Component 200 merged to component 196.
#
#
# Timestep 408
# Component 196 merged to component 107.
#
# -------------------
# COMPONENT 197
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 467
# Component 199 merged to component 197.
#
#
# Timestep 487
# Component 197 merged to component 0.
#
# -------------------
# COMPONENT 198
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 355
# Component 198 merged to component 196.
#
# -------------------
# COMPONENT 199
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 450
# Component 201 merged to component 199.
#
#
# Timestep 467
# Component 199 merged to component 197.
#
# -------------------
# COMPONENT 200
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 349
# Component 202 merged to component 200.
#
#
# Timestep 373
# Component 206 merged to component 200.
#
#
# Timestep 379
# Component 208 merged to component 200.
#
#
# Timestep 384
# Component 200 merged to component 196.
#
# -------------------
# COMPONENT 201
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 434
# Component 203 merged to component 201.
#
#
# Timestep 442
# Component 205 merged to component 201.
#
#
# Timestep 450
# Component 201 merged to component 199.
#
# -------------------
# COMPONENT 202
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 344
# Component 204 merged to component 202.
#
#
# Timestep 349
# Component 202 merged to component 200.
#
# -------------------
# COMPONENT 203
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 434
# Component 203 merged to component 201.
#
# -------------------
# COMPONENT 204
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 344
# Component 204 merged to component 202.
#
# -------------------
# COMPONENT 205
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 442
# Component 205 merged to component 201.
#
# -------------------
# COMPONENT 206
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 373
# Component 206 merged to component 200.
#
# -------------------
# COMPONENT 207
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 423
# Component 209 merged to component 207.
#
#
# Timestep 492
# Component 207 merged to component 0.
#
# -------------------
# COMPONENT 208
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 375
# Component 210 merged to component 208.
#
#
# Timestep 379
# Component 208 merged to component 200.
#
# -------------------
# COMPONENT 209
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 423
# Component 209 merged to component 207.
#
# -------------------
# COMPONENT 210
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 347
# Component 212 merged to component 210.
#
#
# Timestep 375
# Component 210 merged to component 208.
#
# -------------------
# COMPONENT 211
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 449
# Component 214 merged to component 211.
#
#
# Timestep 452
# Component 216 merged to component 211.
#
#
# Timestep 473
# Component 211 merged to component 0.
#
# -------------------
# COMPONENT 212
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 347
# Component 212 merged to component 210.
#
# -------------------
# COMPONENT 213
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 340
# Component 215 merged to component 213.
#
#
# Timestep 403
# Component 213 merged to component 0.
#
# -------------------
# COMPONENT 214
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 449
# Component 214 merged to component 211.
#
# -------------------
# COMPONENT 215
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 340
# Component 215 merged to component 213.
#
# -------------------
# COMPONENT 216
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 452
# Component 216 merged to component 211.
#
# -------------------
# COMPONENT 217
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 342
# Component 219 merged to component 217.
#
#
# Timestep 372
# Component 217 merged to component 0.
#
# -------------------
# COMPONENT 218
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 443
# Component 220 merged to component 218.
#
#
# Timestep 465
# Component 218 merged to component 0.
#
# -------------------
# COMPONENT 219
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 342
# Component 219 merged to component 217.
#
# -------------------
# COMPONENT 220
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 443
# Component 220 merged to component 218.
#
# -------------------
# COMPONENT 221
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 330
# Component 221 merged to component 0.
#
# -------------------
# COMPONENT 222
#
# Timestep 0
# dimension = 0
# determinant = 1.00
# det. ratio  = 1.00
# basis =
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]
# cvs =
# []
#
#
# Timestep 310
# Component 222 merged to component 0.

# %% [markdown]
# ## Example: Doubled Cell

# %%
# doubled cell  
N = 2
a,b,c = 1,1,1
single_points = gen_points(N, a, b, c)
single_example = ExamplePrint(single_points, a=a, b=b, c=c)
single_example.calculate_pph()
#single_example.describe_evolution()
single_example.plot_evolution(cont_timesteps = True, width=7, height=10)


shifted_points = single_points + np.array([[a,0,0] for i in range(N)])
double_points = np.concatenate((single_points, shifted_points), axis=0)
double_example = ExamplePrint(double_points, a=2*a, b=b, c=c)
double_example.calculate_pph()
#double_example.describe_evolution()
double_example.plot_evolution(cont_timesteps = True, width=7, height=10)
# Out:
# every number was covered
# every number was covered

# %% [markdown]
# # End
